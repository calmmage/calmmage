# %%
print(1)

# %%
from PIL import Image

def convert_webp_to_png_jpg(input_webp, output_png):# , output_jpg):
    # Open the WebP image file
    with Image.open(input_webp) as image:
        # Convert the image to PNG and save it
        image.save(output_png, 'PNG')
        # Convert the image to JPEG and save it
        # image.save(output_jpg, 'JPEG')

# Example usage
# input_webp = 'input_image.webp'
# output_png = 'output_image.png'
# output_jpg = 'output_image.jpg'
# 
# convert_webp_to_png_jpg(input_webp, output_png, output_jpg)

# %%
from pathlib import Path
start_path = Path("/Users/calm/Downloads/asd/New Folder With Items")

# get all files in the directory that are webp
webp_files = list(start_path.glob('**/*.webp'))
for webp_file in webp_files:
    # get the output file names
    output_png = webp_file.with_suffix('.png')
    # output_jpg = webp_file.with_suffix('.jpg')
    # convert the webp file to png and jpg
    convert_webp_to_png_jpg(webp_file, output_png)#, output_jpg)
