# %%
print(1)
#
# - 1 - database
# - 2 - connection to telethon, session
# - 3 - get chats
# - 4 - yaml config
# - 5 - get messages
from dotenv import load_dotenv

load_dotenv()
# Out:
# 1
# True

# %% [markdown]
# # Part 1 - Database

# %%
# Out:
# mongodb+srv://petrlavrov:f8ssZM6H4Cvux4Uq@petrlavrovserverless.prced.mongodb.net/

# %%
# option 1 - mongodb pymongo client
from pymongo import MongoClient
import os
from loguru import logger

logger.info("Starting MongoDB setup...")

# Get MongoDB connection string and database name from environment variables
conn_str = os.getenv("MONGO_CONN_STR")
db_name = os.getenv("MONGO_DB_NAME", "telegram-messages-dec-2024")

logger.info(f"Using database name: {db_name}")
logger.info("Attempting to connect to MongoDB...")

# Connect to MongoDB
client = MongoClient(conn_str)
logger.info("Successfully connected to MongoDB")

# MongoDB creates databases and collections automatically when you first store data
# But we can explicitly create them to ensure they exist
logger.info("Checking if database exists...")
if db_name not in client.list_database_names():
    logger.info(f"Creating database: {db_name}")
    db = client[db_name]
else:
    logger.info(f"Using existing database: {db_name}")
    db = client[db_name]

# Define collections we'll need
collections = {
    "messages": "telegram_messages",
    "chats": "telegram_chats",
    "users": "telegram_users",
    "heartbeats": "telegram_heartbeats"
}

logger.info("Starting collection setup...")

# Create collections if they don't exist
for purpose, collection_name in collections.items():
    logger.info(f"Checking collection: {collection_name}")
    if collection_name not in db.list_collection_names():
        logger.info(f"Creating collection: {collection_name}")
        db.create_collection(collection_name)
    else:
        logger.info(f"Using existing collection: {collection_name}")

logger.info("Collection setup complete")

# add item, read items - to the test heartbeats collection
logger.info("Testing heartbeats collection...")
heartbeats_collection = db.heartbeats
from datetime import datetime

logger.info("Inserting test heartbeat...")
heartbeats_collection.insert_one({"timestamp": datetime.now()})
logger.info("Reading test heartbeat...")
heartbeats_collection.find_one()
logger.info("MongoDB setup complete")
# Out:
# 2024-12-29 19:34:01.414 | INFO     | __main__:<module>:6 - Starting MongoDB setup...
# 2024-12-29 19:34:01.414 | INFO     | __main__:<module>:12 - Using database name: dev-telegram-messages-dec-2024
# 2024-12-29 19:34:01.414 | INFO     | __main__:<module>:13 - Attempting to connect to MongoDB...
# 2024-12-29 19:34:01.578 | INFO     | __main__:<module>:17 - Successfully connected to MongoDB
# 2024-12-29 19:34:01.579 | INFO     | __main__:<module>:21 - Checking if database exists...
# 2024-12-29 19:34:01.771 | INFO     | __main__:<module>:26 - Using existing database: dev-telegram-messages-dec-2024
# 2024-12-29 19:34:01.772 | INFO     | __main__:<module>:37 - Starting collection setup...
# 2024-12-29 19:34:01.772 | INFO     | __main__:<module>:41 - Checking collection: telegram_messages
# 2024-12-29 19:34:01.793 | INFO     | __main__:<module>:46 - Using existing collection: telegram_messages
# 2024-12-29 19:34:01.794 | INFO     | __main__:<module>:41 - Checking collection: telegram_chats
# 2024-12-29 19:34:01.815 | INFO     | __main__:<module>:46 - Using existing collection: telegram_chats
# 2024-12-29 19:34:01.816 | INFO     | __main__:<module>:41 - Checking collection: telegram_users
# 2024-12-29 19:34:01.837 | INFO     | __main__:<module>:46 - Using existing collection: telegram_users
# 2024-12-29 19:34:01.838 | INFO     | __main__:<module>:41 - Checking collection: telegram_heartbeats
# 2024-12-29 19:34:01.860 | INFO     | __main__:<module>:46 - Using existing collection: telegram_heartbeats
# 2024-12-29 19:34:01.860 | INFO     | __main__:<module>:48 - Collection setup complete
# 2024-12-29 19:34:01.860 | INFO     | __main__:<module>:51 - Testing heartbeats collection...
# 2024-12-29 19:34:01.861 | INFO     | __main__:<module>:54 - Inserting test heartbeat...
# 2024-12-29 19:34:01.917 | INFO     | __main__:<module>:56 - Reading test heartbeat...
# 2024-12-29 19:34:01.939 | INFO     | __main__:<module>:58 - MongoDB setup complete

# %%
client, db
# Out:
# (MongoClient(host=['petrlavrovserverless-lb.prced.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', loadbalanced=True, tls=True),
#  Database(MongoClient(host=['petrlavrovserverless-lb.prced.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', loadbalanced=True, tls=True), 'dev-telegram-messages-dec-2024'))

# %% [markdown]
# # Part 2 - Connection to Telethon

# %%
# 1 - general "get_telethon_client" function
# trajectory 1: save and load conn from disk
# 2 - create new conn from scratch -> save conn to disk
# 3 - check if conn is present on disk
# 4 - load conn from disk
# trajectoty 2: save conn to db
# 5 - create new conn from scratch -> save conn to db
# 6 - load conn from db
# 7 - check if conn is present in db

# %% [markdown]
# Trajectory 1: Save and load connection from disk

# %%
from enum import Enum


class StorageMode(str, Enum):
    TO_DATABASE = "to_database"
    TO_DISK = "to_disk"


class TelethonClientManager:
    def __init__(self, storage_mode: StorageMode):
        self.storage_mode = storage_mode

    def get_telethon_client(self, user_id):
        if self.storage_mode == StorageMode.TO_DISK:
            return _get_telethon_client_from_disk(user_id)
        elif self.storage_mode == StorageMode.TO_DATABASE:
            return _get_telethon_client_from_database(user_id)

    # region trajectory 1 save and load conn from disk
    def _get_telethon_client_from_disk(self, user_id):

        if self._check_if_conn_is_present_on_disk(user_id):
            return self._load_conn_from_disk(user_id)
        else:
            return self._create_new_telethon_client_and_save_to_disk(user_id)

    # 2 - create new conn from scratch -> save conn to disk
    def _create_new_telethon_client_and_save_to_disk(self, user_id):
        pass

    # 3 - check if conn is present on disk
    def _check_if_conn_is_present_on_disk(self, user_id):
        pass

    # 4 - load conn from disk
    def _load_conn_from_disk(self, user_id):
        pass

    # endregion trajectory 1

    # region trajectory 2 save conn to db
    def _get_telethon_client_from_database(self, user_id):
        raise NotImplementedError

    # 5 - create new conn from scratch -> save conn to db
    def _create_new_telethon_client_and_save_to_db(self, user_id):
        pass

    # 6 - load conn from db
    def _load_conn_from_db(self, user_id):
        pass

    # 7 - check if conn is present in db
    def _check_if_conn_is_present_in_db(self, user_id):
        pass

    # endregion trajectory 2

# %% [markdown]
# Trajectory 2: Create new connection from scratch -> save connection to disk

# %% [markdown]
# # Part 3 - Get Chats

# %%
# idea 1: just load chat list
# idea 2: cache chat list. Save timestamp. If timestamp is older than 1 day, load chat list.
# idea 3: add --refresh flag. If flag is set, load chat list from scratch.
# idea 4: calculate fancy stats about chats.
# Basic:
# private messages
# group chats
# channels
# bots

# Advanced:
# owned groups
# owned bots
# owned channels

# big groups (> 1000)
# big channels

# Bonus: size / time-based stats
# for each of the above - count which have recent messages (last 30 days)

import pickle
from main import get_telethon_client
from loguru import logger
import asyncio
from utils import setup_logger
from pathlib import Path
import json
from pydantic import BaseModel
from datetime import datetime
from typing import List
from telethon.tl.custom import Dialog

# class ChatCache(BaseModel):
#     timestamp: datetime
#     chats: List[Dialog]

# async def save_chat_cache(chats: List[Dialog], cache_file: Path = Path("data/chat_cache.json")):
#     """Save chat list to cache file with timestamp"""
#     cache_data = ChatCache(
#         timestamp=datetime.now(),
#         chats=chats
#     )
#
#     cache_file.parent.mkdir(exist_ok=True)
#     cache_file.write_text(cache_data.model_dump_json(indent=2))
#     logger.debug(f"Saved chat cache to {cache_file}")
import nest_asyncio

nest_asyncio.apply()


# Load our extension
# %load_ext telethon_jupyter

async def get_chat_list() -> List[Dialog]:
    client = await get_telethon_client()
    chats = await client.get_dialogs()
    return chats


# Store chats in memory
chats = asyncio.run(get_chat_list())

# Now you can work with them directly:
print("Total chats:", len(chats))
print("\nExample chats:")
for chat in chats[:5]:  # Show first 5 chats
    print(chat)

# Filter and analyze:
groups = [chat for chat in chats if chat.is_group]
channels = [chat for chat in chats if chat.is_channel]
users = [chat for chat in chats if chat.is_user]

print(f"\nFound {len(groups)} groups, {len(channels)} channels, {len(users)} users")

# Find largest groups
largest_groups = sorted(
    [chat for chat in groups if hasattr(chat.entity, 'participants_count')],
    key=lambda x: getattr(x.entity, 'participants_count', 0),
    reverse=True
)[:5]

print("\nLargest groups:")
for chat in largest_groups:
    print(f"{chat.entity.title}: {chat.entity.participants_count} members")
# Out:
# 2024-12-29 19:34:19.605 | DEBUG    | telethon_manager:__init__:24 - TelethonManager initialized with storage_mode: StorageMode.TO_DISK
# 2024-12-29 19:34:19.605 | DEBUG    | telethon_manager:__init__:25 - TelethonManager initialized with sessions dir: sessions
# 2024-12-29 19:34:19.606 | DEBUG    | telethon_manager:get_telethon_client:28 - Getting telethon client for user 291560340 with storage mode StorageMode.TO_DISK
# 2024-12-29 19:34:19.606 | DEBUG    | telethon_manager:_get_telethon_client_from_disk:36 - Attempting to get telethon client from disk for user 291560340
# 2024-12-29 19:34:19.606 | DEBUG    | telethon_manager:_check_if_conn_is_present_on_disk:115 - Checking if session file exists for user 291560340: True
# 2024-12-29 19:34:19.606 | DEBUG    | telethon_manager:_get_telethon_client_from_disk:38 - Found existing connection on disk for user 291560340
# 2024-12-29 19:34:19.606 | DEBUG    | telethon_manager:_load_conn_from_disk:122 - Loading session for user 291560340 from sessions/user_291560340.session
# 2024-12-29 19:34:19.607 | DEBUG    | telethon_manager:_load_conn_from_disk:130 - Attempting to connect existing client for user 291560340
# 2024-12-29 19:34:19.822 | DEBUG    | telethon_manager:_load_conn_from_disk:134 - Session authorization check for user 291560340: True
# 2024-12-29 19:34:19.822 | DEBUG    | telethon_manager:_load_conn_from_disk:138 - Successfully loaded and authorized client for user 291560340
# Total chats: 1779
#
# Example chats:
# Dialog(name='CalmMage Daily Meditation', date=datetime.datetime(2024, 12, 5, 16, 35, 2, tzinfo=datetime.timezone.utc), draft=<telethon.tl.custom.draft.Draft object at 0x11b511a10>, message=Message(id=27, peer_id=PeerChannel(channel_id=2373457856), date=datetime.datetime(2024, 12, 5, 16, 35, 2, tzinfo=datetime.timezone.utc), message='Я утешаюсь гитарой', out=False, mentioned=True, media_unread=False, silent=False, post=False, from_scheduled=False, legacy=False, edit_hide=False, pinned=False, noforwards=False, invert_media=False, offline=False, video_processing_pending=False, from_id=PeerUser(user_id=387021315), from_boosts_applied=None, saved_peer_id=None, fwd_from=None, via_bot_id=None, via_business_bot_id=None, reply_to=MessageReplyHeader(reply_to_scheduled=False, forum_topic=False, quote=False, reply_to_msg_id=23, reply_to_peer_id=None, reply_from=None, reply_media=None, reply_to_top_id=None, quote_text=None, quote_entities=[], quote_offset=None), media=None, reply_markup=None, entities=[], views=None, forwards=None, replies=None, edit_date=None, post_author=None, grouped_id=None, reactions=None, restriction_reason=[], ttl_period=None, quick_reply_shortcut_id=None, effect=None, factcheck=None), entity=Channel(id=2373457856, title='CalmMage Daily Meditation', photo=ChatPhoto(photo_id=5221936468610636825, dc_id=2, has_video=False, stripped_thumb=b'\x01\x08\x08\xa5\xb5~\xcf\x9e(\xa2\x8a`\x7f'), date=datetime.datetime(2024, 10, 7, 6, 39, 16, tzinfo=datetime.timezone.utc), creator=True, left=False, broadcast=False, verified=False, megagroup=True, restricted=False, signatures=False, min=False, scam=False, has_link=False, has_geo=False, slowmode_enabled=False, call_active=False, call_not_empty=False, fake=False, gigagroup=False, noforwards=False, join_to_send=False, join_request=False, forum=False, stories_hidden=False, stories_hidden_min=False, stories_unavailable=True, signature_profiles=False, access_hash=8371095179012486494, username=None, restriction_reason=[], admin_rights=ChatAdminRights(change_info=True, post_messages=True, edit_messages=True, delete_messages=True, ban_users=True, invite_users=True, pin_messages=True, add_admins=True, anonymous=False, manage_call=True, other=True, manage_topics=True, post_stories=True, edit_stories=True, delete_stories=True), banned_rights=None, default_banned_rights=ChatBannedRights(until_date=datetime.datetime(2038, 1, 19, 3, 14, 7, tzinfo=datetime.timezone.utc), view_messages=False, send_messages=False, send_media=False, send_stickers=False, send_gifs=False, send_games=False, send_inline=False, embed_links=False, send_polls=False, change_info=False, invite_users=False, pin_messages=False, manage_topics=False, send_photos=False, send_videos=False, send_roundvideos=False, send_audios=False, send_voices=False, send_docs=False, send_plain=False), participants_count=6, usernames=[], stories_max_id=None, color=None, profile_color=None, emoji_status=None, level=None, subscription_until_date=None))
# Dialog(name='EF Once-a-week Challenges', date=datetime.datetime(2024, 11, 18, 20, 54, 10, tzinfo=datetime.timezone.utc), draft=<telethon.tl.custom.draft.Draft object at 0x11b511bd0>, message=Message(id=50, peer_id=PeerChannel(channel_id=2332193270), date=datetime.datetime(2024, 11, 18, 20, 54, 10, tzinfo=datetime.timezone.utc), message='', out=False, mentioned=False, media_unread=False, silent=False, post=False, from_scheduled=False, legacy=False, edit_hide=True, pinned=False, noforwards=False, invert_media=False, offline=False, video_processing_pending=False, from_id=PeerUser(user_id=139463400), from_boosts_applied=None, saved_peer_id=None, fwd_from=None, via_bot_id=None, via_business_bot_id=None, reply_to=None, media=MessageMediaPhoto(spoiler=False, photo=Photo(id=5900123486960075958, access_hash=5569893366217239023, file_reference=b'\x05\x00\x00\x00\x00\x8b\x02q\xf6\x00\x00\x002gqz\x120\x94\x1b\x9e\x8cZ{\xbd5W\x80n\x93\xa5\x10k', date=datetime.datetime(2024, 11, 18, 20, 54, 10, tzinfo=datetime.timezone.utc), sizes=[PhotoStrippedSize(type='i', bytes=b'\x01((\xd1\x19\xcfN(s\xb5s\x9c~\x19\xa7\n\n\xb6s\xbc\x81\xe9\x81LD>b\xff\x00}\xbf\xef\x8e\x94\xf4;\x86A\xc8\xfab\x9d\xb1\x86\x7fx\x7f!@B\x0eK\x93\xed@\x08sE8\xd1@\n\xb4\xb4\xcc\xf1\xc7Zvx\xcd\x006V\xdb\x13\xb7]\xa0\x9cR\xc4wB\x8d\x8e\xa0\x1a\x8ac\xfb\x99}\xd4\xff\x00*|\x1f\xf1\xed\x17\xfb\x83\xf9P\x03\x89\x19\xc7z(4P\x03\x01\xa7\x1e\x94Q@\x86H\x9b\xa3e\xcfQ\x8f\xd3\x14\xb1\x8d\x91*\x9f\xe1\x00QE\x00)4QE\x00\x7f'), PhotoSize(type='m', w=320, h=320, size=18708), PhotoSize(type='x', w=800, h=800, size=73902), PhotoSizeProgressive(type='y', w=1280, h=1280, sizes=[13370, 21634, 27310, 42060, 86222])], dc_id=4, has_stickers=False, video_sizes=[]), ttl_seconds=None), reply_markup=None, entities=[], views=None, forwards=None, replies=MessageReplies(replies=0, replies_pts=69, comments=False, recent_repliers=[], channel_id=None, max_id=None, read_max_id=None), edit_date=datetime.datetime(2024, 11, 19, 7, 40, 49, tzinfo=datetime.timezone.utc), post_author=None, grouped_id=None, reactions=MessageReactions(results=[ReactionCount(reaction=ReactionEmoji(emoticon='🔥'), count=1, chosen_order=0)], min=False, can_see_list=True, reactions_as_tags=False, recent_reactions=[MessagePeerReaction(peer_id=PeerUser(user_id=291560340), date=datetime.datetime(2024, 11, 19, 7, 40, 49, tzinfo=datetime.timezone.utc), reaction=ReactionEmoji(emoticon='🔥'), big=False, unread=False, my=False)], top_reactors=[]), restriction_reason=[], ttl_period=None, quick_reply_shortcut_id=None, effect=None, factcheck=None), entity=Channel(id=2332193270, title='EF Once-a-week Challenges', photo=ChatPhoto(photo_id=5188266648019262959, dc_id=2, has_video=False, stripped_thumb=b'\x01\x08\x08\xc7\xc1\xa2\x8a(\x03'), date=datetime.datetime(2024, 10, 2, 15, 21, 27, tzinfo=datetime.timezone.utc), creator=True, left=False, broadcast=False, verified=False, megagroup=True, restricted=False, signatures=False, min=False, scam=False, has_link=False, has_geo=False, slowmode_enabled=False, call_active=False, call_not_empty=False, fake=False, gigagroup=False, noforwards=False, join_to_send=False, join_request=False, forum=False, stories_hidden=False, stories_hidden_min=False, stories_unavailable=True, signature_profiles=False, access_hash=-6133367379904630417, username=None, restriction_reason=[], admin_rights=ChatAdminRights(change_info=True, post_messages=True, edit_messages=True, delete_messages=True, ban_users=True, invite_users=True, pin_messages=True, add_admins=True, anonymous=False, manage_call=True, other=True, manage_topics=True, post_stories=True, edit_stories=True, delete_stories=True), banned_rights=None, default_banned_rights=ChatBannedRights(until_date=datetime.datetime(2038, 1, 19, 3, 14, 7, tzinfo=datetime.timezone.utc), view_messages=False, send_messages=False, send_media=False, send_stickers=False, send_gifs=False, send_games=False, send_inline=False, embed_links=False, send_polls=False, change_info=False, invite_users=False, ...
# Dialog(name='Интересные мысли (без репостов)', date=datetime.datetime(2024, 12, 14, 12, 26, 45, tzinfo=datetime.timezone.utc), draft=<telethon.tl.custom.draft.Draft object at 0x11b511d50>, message=Message(id=15, peer_id=PeerChannel(channel_id=2066938266), date=datetime.datetime(2024, 12, 14, 12, 26, 45, tzinfo=datetime.timezone.utc), message="What I want my life to be in 10 years\n- Impact & Purpose\n - I am directly and significantly positively impacting lives of 10000 people\n - I, my skills and talents are utilized properly and effectively\n- Wisdom & insight\n - I understand this life and what is possible to understand beyond. I expand these horizons with diligent and humble effort.\n- Skill & Intelligence\n - I am in best shape of my life intellectually\n - I have and am developing a collection of practical and useful skills\n- Love & Joy\n - We are in love with Anna and live happy and intimate lives. We play games and have fun\n- Team\n - We're a team with Anna and collaborate together frequently and efficiently\n- Kids\n - We are raising 4+ great kids who we love and who love us\n- Home\n - We live in a mansion that we love with great art, vibe and design\n- Challenge\n - I am doing difficult and challenging for me things on a daily basis. Struggling to overcome in pain and fight.\n- Health\n - I am in perfect health and alacrity. I enjoy and use my body on a daily basis\n- Mind\n - I am perfect in meditation and mindfulness, in taking control and releasing my own mind\n- Adventure & Fun\n - I frequently explore new and unknown for me areas", out=True, mentioned=False, media_unread=False, silent=False, post=False, from_scheduled=False, legacy=False, edit_hide=False, pinned=False, noforwards=False, invert_media=False, offline=False, video_processing_pending=False, from_id=PeerUser(user_id=291560340), from_boosts_applied=None, saved_peer_id=None, fwd_from=None, via_bot_id=None, via_business_bot_id=None, reply_to=None, media=None, reply_markup=None, entities=[], views=None, forwards=None, replies=MessageReplies(replies=0, replies_pts=21, comments=False, recent_repliers=[], channel_id=None, max_id=None, read_max_id=None), edit_date=datetime.datetime(2024, 12, 14, 12, 26, 55, tzinfo=datetime.timezone.utc), post_author=None, grouped_id=None, reactions=None, restriction_reason=[], ttl_period=None, quick_reply_shortcut_id=None, effect=None, factcheck=None), entity=Channel(id=2066938266, title='Интересные мысли (без репостов)', photo=ChatPhotoEmpty(), date=datetime.datetime(2024, 5, 9, 15, 58, 55, tzinfo=datetime.timezone.utc), creator=True, left=False, broadcast=False, verified=False, megagroup=True, restricted=False, signatures=False, min=False, scam=False, has_link=False, has_geo=False, slowmode_enabled=False, call_active=False, call_not_empty=False, fake=False, gigagroup=False, noforwards=False, join_to_send=False, join_request=False, forum=False, stories_hidden=False, stories_hidden_min=False, stories_unavailable=True, signature_profiles=False, access_hash=8055291818134979225, username=None, restriction_reason=[], admin_rights=ChatAdminRights(change_info=True, post_messages=True, edit_messages=True, delete_messages=True, ban_users=True, invite_users=True, pin_messages=True, add_admins=True, anonymous=False, manage_call=True, other=True, manage_topics=True, post_stories=True, edit_stories=True, delete_stories=True), banned_rights=None, default_banned_rights=ChatBannedRights(until_date=datetime.datetime(2038, 1, 19, 3, 14, 7, tzinfo=datetime.timezone.utc), view_messages=False, send_messages=False, send_media=False, send_stickers=False, send_gifs=False, send_games=False, send_inline=False, embed_links=False, send_polls=False, change_info=False, invite_users=False, pin_messages=False, manage_topics=False, send_photos=False, send_videos=False, send_roundvideos=False, send_audios=False, send_voices=False, send_docs=False, send_plain=False), participants_count=2, usernames=[], stories_max_id=None, color=None, profile_color=None, e ...
# Dialog(name='CalmMage Raw (ex. Daily)', date=datetime.datetime(2024, 12, 17, 17, 27, 19, tzinfo=datetime.timezone.utc), draft=<telethon.tl.custom.draft.Draft object at 0x11b512050>, message=Message(id=465, peer_id=PeerChannel(channel_id=2084292315), date=datetime.datetime(2024, 12, 17, 17, 27, 19, tzinfo=datetime.timezone.utc), message='Слайды', out=True, mentioned=False, media_unread=False, silent=False, post=True, from_scheduled=False, legacy=False, edit_hide=True, pinned=False, noforwards=False, invert_media=False, offline=False, video_processing_pending=False, from_id=None, from_boosts_applied=None, saved_peer_id=None, fwd_from=None, via_bot_id=None, via_business_bot_id=None, reply_to=None, media=MessageMediaDocument(nopremium=False, spoiler=False, video=False, round=False, voice=False, document=Document(id=5406605497648308229, access_hash=-4929960538898328506, file_reference=b'\x04|;\xc6\xdb\x00\x00\x01\xd1gqz\x12\x9dJ\x91\xf7s\x84\xde\xb8\xb2\xa0\xde\xc9\xfbU\xe6Q', date=datetime.datetime(2024, 12, 17, 17, 27, 19, tzinfo=datetime.timezone.utc), mime_type='application/pdf', size=2383685, dc_id=2, attributes=[DocumentAttributeFilename(file_name='Thinking with GPT - EPFL, Dec 2024.pdf')], thumbs=[PhotoStrippedSize(type='i', bytes=b'\x01\x16(\xd9\xa2\x8aF]\xc3\xa9\x1fC@\x0bE3a\xcf\xde?\x9d9Wh\xeaO\xd4\xd0\x02\x90\x0fZ(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80?'), PhotoSize(type='m', w=320, h=180, size=3133)], video_thumbs=[]), alt_documents=[], ttl_seconds=None), reply_markup=None, entities=[], views=4, forwards=0, replies=MessageReplies(replies=0, replies_pts=847, comments=True, recent_repliers=[], channel_id=1944275263, max_id=None, read_max_id=None), edit_date=datetime.datetime(2024, 12, 17, 17, 27, 22, tzinfo=datetime.timezone.utc), post_author='Petr Lavrov', grouped_id=None, reactions=None, restriction_reason=[], ttl_period=None, quick_reply_shortcut_id=None, effect=None, factcheck=None), entity=Channel(id=2084292315, title='CalmMage Raw (ex. Daily)', photo=ChatPhoto(photo_id=5388734774841042269, dc_id=2, has_video=True, stripped_thumb=b'\x01\x08\x08\xcc\xfc\xb6\xe2\x8a(\xa0\x0f'), date=datetime.datetime(2023, 12, 4, 23, 55, 19, tzinfo=datetime.timezone.utc), creator=True, left=False, broadcast=True, verified=False, megagroup=False, restricted=False, signatures=True, min=False, scam=False, has_link=True, has_geo=False, slowmode_enabled=False, call_active=False, call_not_empty=False, fake=False, gigagroup=False, noforwards=False, join_to_send=False, join_request=False, forum=False, stories_hidden=False, stories_hidden_min=False, stories_unavailable=True, signature_profiles=False, access_hash=-8609056724084328168, username=None, restriction_reason=[], admin_rights=ChatAdminRights(change_info=True, post_messages=True, edit_messages=True, delete_messages=True, ban_users=True, invite_users=True, pin_messages=True, add_admins=True, anonymous=False, manage_call=True, other=True, manage_topics=True, post_stories=True, edit_stories=True, delete_stories=True), banned_rights=None, default_banned_rights=None, participants_count=7, usernames=[], stories_max_id=None, color=None, profile_color=None, emoji_status=None, level=None, subscription_until_date=None))
# Dialog(name='CalmMage Life', date=datetime.datetime(2024, 12, 28, 19, 46, 14, tzinfo=datetime.timezone.utc), draft=<telethon.tl.custom.draft.Draft object at 0x11b5121d0>, message=Message(id=671, peer_id=PeerChannel(channel_id=1551656064), date=datetime.datetime(2024, 12, 28, 19, 46, 14, tzinfo=datetime.timezone.utc), message='🏋️\u200d♀️Сложно vs Тяжело (Difficult vs Heavy)\n\nМногие мои близкие друзья не раз слышали как я питчил этот коцепт - что есть огромная разница между понятиями "сложно" и "тяжело"\n\nНапример, стоять в планке - тяжело, но очень просто (не сложно). Инструкция элементарна: "тело прямое, стоишь на локтях".\n\n"Да это же легкотня. (Раз, раз, раз - показал)". Кстати, на этом основан другой мой любимый концепт - делиться лёгкостью\n\n---\n\nКстати часто из-за разницы этих понятий и неточного их использования возникают очень эмоциональные разногласия и реакции: "Да чего ты не бросишь курить/пить/гамать. Это же элементарно. Просто берешь и не ..." \nИ эта мысль кажется такой правильной и такой бесспорной..\n\n---\n\nСобственно, есть прямой критерий как их можно отличать: по длине инструкции. Если инструкция простая - дело простое. А если длинная - то сложное.\nТут есть два ответвления мысли:\n- для математиков: Это ровно критерий информационной сложности по Колмогорову \n- Одно и то же дело может для нас переходить из категории сложного в простое, становясь знакомым и упаковываясь в абстракции\n(Но и из простого в сложное - раскрываясь - например, когда понимаешь сколько на самом деле нюансов есть в стоянии в планке)\n\n---\n\nНо есть и другой, казалось бы напрямую несвязанный критерий: скорость времени!\nКогда мы делаем что-то сложное - время ускоряется. Готовимся к экзамену, пишем олимпиаду, читаем книгу. Моргнул - и уже 6 утра.\nА когда что-то тяжёлое - наоборот, замедляется (как тянутся секунды стоя в планке или ожидая в очереди)\n\nКстати, а что происходит со временем если дело и сложное и тяжёлое?🤔 Тот же экзамен...', out=True, mentioned=False, media_unread=False, silent=False, post=True, from_scheduled=False, legacy=False, edit_hide=True, pinned=False, noforwards=False, invert_media=False, offline=False, video_processing_pending=False, from_id=None, from_boosts_applied=None, saved_peer_id=None, fwd_from=MessageFwdHeader(date=datetime.datetime(2024, 12, 28, 12, 10, 2, tzinfo=datetime.timezone.utc), imported=False, saved_out=False, from_id=PeerChannel(channel_id=2196960489), from_name=None, channel_post=18, post_author=None, saved_from_peer=None, saved_from_msg_id=None, saved_from_id=None, saved_from_name=None, saved_date=None, psa_type=None), via_bot_id=None, via_business_bot_id=None, reply_to=None, media=None, reply_markup=None, entities=[MessageEntityCustomEmoji(offset=0, length=6, document_id=5355077035536431940), MessageEntityBold(offset=6, length=37), MessageEntityItalic(offset=326, length=3), MessageEntityBold(offset=331, length=3), MessageEntityItalic(offset=348, length=50), MessageEntityItalic(offset=401, length=18), MessageEntitySpoiler(offset=878, length=328), MessageEntityBold(offset=1468, length=3), MessageEntityItalic(offset=1468, length=3), MessageEntitySpoiler(offset=1525, length=87), MessageEntityItalic(offset=1572, length=1), MessageEntityItalic(offset=1582, length=1)], views=30, forwards=0, replies=MessageReplies(replies=1, replies_pts=1797, comments=True, recent_repliers=[PeerUser(user_id=248178089)], channel_id=1676776557, max_id=1058, read_max_id=None), edit_date=datetime.datetime(2024, 12, 28, 20, 2, 24, tzinfo=datetime.timezone.utc), post_author='Petr Lavrov', grouped_id=None, reactions=MessageReactions(results=[ReactionCount(reaction=ReactionEmoji(emoticon='❤'), count=6, chosen_order=None)], min=False, can_see_list=False, reactions_as_tags=False, recent_reactions=[], top_reactors=[]), restriction_reason=[], ttl_period=None, quick_reply_shortcut_id=None, effect=None, factcheck=None), entity=Channel(id=1551656064, title='CalmMage Life', photo=ChatPhoto(photo_id=5249078797905543323, dc ...
#
# Found 821 groups, 394 channels, 831 users
#
# Largest groups:
# >>> telegram.Bot(): 11511 members
# aiogram: 9268 members
# C++ specialization community|stepik: 3842 members
# Python чат | Питон помощь: 1597 members
# MINDCRAFT: 1122 members
# Server closed the connection: 0 bytes read on a total of 8 expected bytes
# Error executing high-level request after reconnect: <class 'sqlite3.OperationalError'>: database is locked
# Server closed the connection: 0 bytes read on a total of 8 expected bytes
# Error executing high-level request after reconnect: <class 'sqlite3.OperationalError'>: database is locked
# Cannot get difference for channel 2390931683 since the account is likely misusing the session: database is locked
# Unhandled exception from keepalive_handle after cancelling <class 'asyncio.tasks.Task'> (<Task finished name='Task-8' coro=<UpdateMethods._keepalive_loop() done, defined at /Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/client/updates.py:481> exception=OperationalError('database is locked')>)
# Traceback (most recent call last):
#   File "/Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/helpers.py", line 176, in _cancel
#     await task
#   File "/nix/store/cgc094j7jm0dm4xj0v1hy4361pji4ys6-python3-3.11.10/lib/python3.11/asyncio/futures.py", line 290, in __await__
#     return self.result()  # May raise too.
#            ^^^^^^^^^^^^^
#   File "/nix/store/cgc094j7jm0dm4xj0v1hy4361pji4ys6-python3-3.11.10/lib/python3.11/asyncio/futures.py", line 203, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/nix/store/cgc094j7jm0dm4xj0v1hy4361pji4ys6-python3-3.11.10/lib/python3.11/asyncio/tasks.py", line 277, in __step
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "/Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/client/updates.py", line 517, in _keepalive_loop
#     self._save_states_and_entities()
#   File "/Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/client/telegrambaseclient.py", line 693, in _save_states_and_entities
#     self.session.process_entities(types.contacts.ResolvedPeer(None, [e._as_input_peer() for e in entities], []))
#   File "/Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/sessions/sqlite.py", line 301, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked

# %%
# Get one chat and explore its attributes
chat = chats[0]

print("Basic chat info:")
print(f"Title: {chat.title}")
print(f"ID: {chat.id}")
print(f"Type: {'channel' if chat.is_channel else 'group' if chat.is_group else 'user'}")
print(f"Unread: {chat.unread_count}")

# Look at the entity object
print("\nEntity attributes:")
for attr in dir(chat.entity):
    if not attr.startswith('_'):  # Skip private attributes
        print(f"{attr}: {getattr(chat.entity, attr)}")
# Out:
# Basic chat info:
# Title: CalmMage Daily Meditation
# ID: -1002373457856
# Type: channel
# Unread: 0
#
# Entity attributes:
# CONSTRUCTOR_ID: 4265900221
# SUBCLASS_OF_ID: 3316604308
# access_hash: 8371095179012486494
# admin_rights: ChatAdminRights(change_info=True, post_messages=True, edit_messages=True, delete_messages=True, ban_users=True, invite_users=True, pin_messages=True, add_admins=True, anonymous=False, manage_call=True, other=True, manage_topics=True, post_stories=True, edit_stories=True, delete_stories=True)
# banned_rights: None
# broadcast: False
# call_active: False
# call_not_empty: False
# color: None
# creator: True
# date: 2024-10-07 06:39:16+00:00
# default_banned_rights: ChatBannedRights(until_date=datetime.datetime(2038, 1, 19, 3, 14, 7, tzinfo=datetime.timezone.utc), view_messages=False, send_messages=False, send_media=False, send_stickers=False, send_gifs=False, send_games=False, send_inline=False, embed_links=False, send_polls=False, change_info=False, invite_users=False, pin_messages=False, manage_topics=False, send_photos=False, send_videos=False, send_roundvideos=False, send_audios=False, send_voices=False, send_docs=False, send_plain=False)
# emoji_status: None
# fake: False
# forum: False
# from_reader: <bound method Channel.from_reader of <class 'telethon.tl.types.Channel'>>
# gigagroup: False
# has_geo: False
# has_link: False
# id: 2373457856
# join_request: False
# join_to_send: False
# left: False
# level: None
# megagroup: True
# min: False
# noforwards: False
# participants_count: 6
# photo: ChatPhoto(photo_id=5221936468610636825, dc_id=2, has_video=False, stripped_thumb=b'\x01\x08\x08\xa5\xb5~\xcf\x9e(\xa2\x8a`\x7f')
# pretty_format: <function TLObject.pretty_format at 0x10d9b0b80>
# profile_color: None
# restricted: False
# restriction_reason: None
# scam: False
# serialize_bytes: <function TLObject.serialize_bytes at 0x10d9b0c20>
# serialize_datetime: <function TLObject.serialize_datetime at 0x10d9b0cc0>
# signature_profiles: False
# signatures: False
# slowmode_enabled: False
# stories_hidden: False
# stories_hidden_min: False
# stories_max_id: None
# stories_unavailable: True
# stringify: <bound method TLObject.stringify of <telethon.tl.types.Channel object at 0x119c664d0>>
# subscription_until_date: None
# title: CalmMage Daily Meditation
# to_dict: <bound method Channel.to_dict of <telethon.tl.types.Channel object at 0x119c664d0>>
# to_json: <bound method TLObject.to_json of <telethon.tl.types.Channel object at 0x119c664d0>>
# username: None
# usernames: None
# verified: False

# %%
# Admin status
print("Admin status:")
print(f"creator: {chat.entity.creator}")
print(f"admin_rights: {chat.entity.admin_rights}")

# Size
print("\nSize:")
print(f"participants_count: {chat.entity.participants_count}")

# Type indicators
print("\nType indicators:")
print(f"broadcast: {chat.entity.broadcast}")
print(f"megagroup: {chat.entity.megagroup}")

# Features
print("\nFeatures:")
print(f"forum: {chat.entity.forum}")
print(f"username: {chat.entity.username}")
print(f"verified: {chat.entity.verified}")
# Out:
# Admin status:
# creator: True
# admin_rights: ChatAdminRights(change_info=True, post_messages=True, edit_messages=True, delete_messages=True, ban_users=True, invite_users=True, pin_messages=True, add_admins=True, anonymous=False, manage_call=True, other=True, manage_topics=True, post_stories=True, edit_stories=True, delete_stories=True)
#
# Size:
# participants_count: 6
#
# Type indicators:
# broadcast: False
# megagroup: True
#
# Features:
# forum: False
# username: None
# verified: False

# %%
ALLOWED = False
# ALLOWED=True

if not ALLOWED:
    print(
        "Old code version with naive implementation. Category counts don't sum up to total chats. - reesarch about this below.")
else:

    # Basic counts
    private_chats = [c for c in chats if c.is_user and not getattr(c.entity, 'bot',
                                                                   False)]  # Fixed private chat detection
    groups = [c for c in chats if c.is_group]
    channels = [c for c in chats if c.is_channel]
    bots = [c for c in chats if c.is_user and getattr(c.entity, 'bot', True)]


    def get_creator(chat):
        try:
            return chat.entity.creator
        except:
            return None


    # Ownership counts
    owned_groups = [c for c in groups if get_creator(c)]
    owned_channels = [c for c in channels if get_creator(c)]
    owned_bots = [c for c in bots if get_creator(c)]  # Added bot ownership

    print("Chat Statistics:")
    print(f"Private chats: {len(private_chats)}")

    print(f"\nGroups: {len(groups)}")
    print(f"  - owned: {len(owned_groups)}")

    print(f"\nChannels: {len(channels)}")
    print(f"  - owned: {len(owned_channels)}")

    print(f"\nBots: {len(bots)}")
    print(f"  - owned: {len(owned_bots)}")
# Out:
# Chat Statistics:
# Private chats: 732
#
# Groups: 821
#   - owned: 512
#
# Channels: 394
#   - owned: 202
#
# Bots: 99
#   - owned: 0

# %%
ALLOWED = False
# ALLOWED=True

if not ALLOWED:
    print(
        "Deprecated research code, research finished. Findings: groups with message history enabled are marked as channels in telethon - need to work around that for correct stats.")
else:
    # Let's debug our categorization
    total_chats = len(chats)
    private_chats = [c for c in chats if
                     c.is_user and not getattr(c.entity, 'bot', False)]
    groups = [c for c in chats if c.is_group]
    channels = [c for c in chats if c.is_channel]
    bots = [c for c in chats if c.is_user and getattr(c.entity, 'bot', True)]

    # Verify our counts
    categorized = len(private_chats) + len(groups) + len(channels) + len(bots)

    print("Verification:")
    print(f"Total chats: {total_chats}")
    print(f"Sum of categories: {categorized}")
    print(f"Difference: {total_chats - categorized}")

    # Let's check if any chats are uncategorized or double-counted
    uncategorized = []
    for chat in chats:
        categories = []
        if chat.is_user and not getattr(chat.entity, 'bot', False):
            categories.append('private')
        if chat.is_group:
            categories.append('group')
        if chat.is_channel:
            categories.append('channel')
        if chat.is_user and getattr(chat.entity, 'bot', True):
            categories.append('bot')

        if len(categories) != 1:
            # print(f"\nChat '{chat.title}' belongs to categories: {categories}")
            pass
        elif 'group' in categories:
            print(f"Group chat: {chat.title}")
# Out:
# Verification:
# Total chats: 1779
# Sum of categories: 2046
# Difference: -267
# Group chat: Лавровы и Женя+Дима
# Group chat: Поездка Турция Лавровы калкан йога 2024 Petr, Наталья and Anna
# Group chat: Здоровье, Health
# Group chat: 146: Марина, Петя, Ваня
# Group chat: Путешествия Lavrov #travel
# Group chat: 146: Оргкоммитет стратсессии
# Group chat: CHF RUB currency exchange Switzerland
# Group chat: Лавровы и Ирина
# Group chat: Лавровы и Ира+Саша
# Group chat: Поздравления/feedback
# Group chat: Соседи))
# Group chat: Все о детях Kids Children
# Group chat: 146: развитие сообщества
# Group chat: Лавровы и Даня+Мира
# Group chat: Family Videos and GIFs
# Group chat: Квартира 834
# Group chat: Wishlist 2024
# Group chat: Кого звать на йогу Yoga
# Group chat: Тренируемся стабильно
# Group chat: Лавровый и Ершовы, НеДеды
# Group chat: Петр Лавров, Кирилл Коновалов
# Group chat: Taxes
# Group chat: Family Space - Tasks, notes and projects
# Group chat: Лавровы и Тюрины (Mature and wise)
# Group chat: Лавровы и Маша
# Group chat: EF Gaming - Factorio: Space Age
# Group chat: AI Codes - чат для разработчиков про Cursor, Copilot и другие AI dev tools
# Group chat: Coworking Petr & Айнур
# Group chat: Проект 146: Аналитика
# Group chat: Кристина, Ваня и Петя
# Group chat: Проект 146: Помощь учителям, школе - 2.0
# Group chat: Проект 146: Хакатон
# Group chat: Режим график Даши
# Group chat: How to procrastinate
# Group chat: Лавровы и Водолагины
# Group chat: Лавровы и Коля
# Group chat: Поездка мамы в Цюрих
# Group chat: Проект 146 - Петя Саша
# Group chat: Лавровы и Марина Б
# Group chat: Проект: Бот клуба 146
# Group chat: Проект: Книжный клуб 146
# Group chat: Petr, Leonid and Ivan
# Group chat: Лавровы и Филипп
# Group chat: 146 - Рома, Ваня, Петя
# Group chat: 146: Эксперименты
# Group chat: EF Meditation Challenge
# Group chat: 146: Logs. Архив добавления в группу
# Group chat: Mikhail, Aleksei & Mark
# Group chat: EF Requests Log
# Group chat: EF Once-a-week Challenges
# Group chat: Petr & Mark, Lev
# Group chat: Петя, Роберт, интро
# Group chat: Семья - Дима, Лева и Робик
# Group chat: 146: встреча 20 октября 2024 в Цюрхие
# Group chat: Поездка в Россию
# Group chat: Менторство 146: Intro Диана and Anna
# Group chat: E F Challenges
# Group chat: Intro: Petr, Mark and Dmitry
# Group chat: ЖБЧ оффлайн - 18 августа
# Group chat: 146: PR chat
# Group chat: [Архив] Курсы 146 Тинькофф
# Group chat: Petr, Даниэль and Марк
# Group chat: Побег в Цюрихе
# Group chat: Эксперимент: Учим немецкий
# Group chat: Эксперимент: Travelling Parents
# Group chat: Эксперимент: Kinder-хакинг
# Group chat: Intro - Petr, Михаил and Mikhail
# Group chat: Projects and Interviews - Mikhail, Lev
# Group chat: Математические игры на юбилей
# Group chat: Лавровы, Ваня и Булат
# Group chat: Проект 146: Эксперименты
# Group chat: Йога 2024 - Орг чат
# Group chat: Интенсив Йога Калкан 2024
# Group chat: Coach session for Elena
# Group chat: Менторы 146
# Group chat: Zurich: Life, Chores and Vanya
# Group chat: Лавровы и Мокины
# Group chat: LLM in Enterprise - Petr, Сергей and Mikhail
# Group chat: EF onboarding: Аня Масальцева
# Group chat: Work Tasks and Ideas
# Group chat: Petr & Mikhail, Михаил
# Group chat: Тред про собесы)
# Group chat: Пробная игра к юбилею
# Group chat: 146: Мобильное приложение, сайт и чат-бот клуба
# Group chat: 146: Thinking about SMM
# Group chat: 146 онлайн юбилей: ЖБЧ
# Group chat: Сыновья
# Group chat: Люди и контакты, Random people contacts
# Group chat: Сыр Cheese
# Group chat: Petr & Tim, Марк
# Group chat: EF Reminders
# Group chat: EF onboarding: Володя Чепчик
# Group chat: Code Snippets
# Group chat: Daily Plan - History, Archive, Backup
# Group chat: Gpt geeks
# Group chat: Проект 146: Менторство, Коучинг, База знаний
# Group chat: Холодный душ июль | Вотяков закрытая подписка челлендж
# Group chat: Work & Career
# Group chat: Проект 146: Юбилейный Выпуск ШОР
# Group chat: Philosophy into
# Group chat: Info Inbox - Archivist Bot
# Group chat: [Archive] Ideas and Todos Jan 2022
# Group chat: [Archive] AA: Archivist bot ideas
# Group chat: Petr, Андрей and Марк
# Group chat: Петя и Аня, Мама
# Group chat: D3
# Group chat: Костя, Mark, Петя
# Group chat: Лавровы и Марк
# Group chat: Hobby: Networking
# Group chat: Про еду. Petr & Ульяна, Anna
# Group chat: Яхт регата Турция 26 окт - 2 ноя
# Group chat: Intro - Petr & Марк, Aynur
# Group chat: [Archive] Petr and Олег - GPT apps
# Group chat: Coworking - Petr, Alex and Илья
# Group chat: Intro - Petr & Марк, Анна
# Group chat: [Проект 146] Работа с Активистами
# Group chat: Intro - Petr & Марк, Pavel
# Group chat: Горы. Походы. Витечка.
# Group chat: Intro - Petr & Володя, Марк
# Group chat: [Coworking] Petr & Марк - Telegram bot
# Group chat: Проект 146: Сайт, Группы выпускников, Встречи выпускников
# Group chat: Проект 146: Random Coffee, Speed dating, Выпускник-выпускник или выпускник-школьник
# Group chat: Проект 146: Лекторий выпускников
# Group chat: [Coworking] Petr & Марк - App Development
# Group chat: Petr and Victor Coworking
# Group chat: Petr, Tim and Alex
# Group chat: Petr and Robert - Coworking,поиск ассистентов
# Group chat: Petr and Илья - UI/UX for Apple / AVP / LLM apps
# Group chat: Intro Danil and Коля
# Group chat: Интересные мысли (без репостов)
# Group chat: Йога интенсив Швейцария 2024б
# Group chat: EF Coworking - LLM/LangChain - Petr and Георгий
# Group chat: Marina / Mikhail intro
# Group chat: Эксперимент 146: задачи для выпускников
# Group chat: EF Random Coffee
# Group chat: Mark / Marina intro - Engineering session
# Group chat: Прогулки на майские
# Group chat: Petr, Ахмет and Mikhail
# Group chat: Triple double
# Group chat: Пицца 1
# Group chat: Опросы в EF
# Group chat: Petr and Марина - Coworking 146
# Group chat: Coworking - Petr & Костя
# Group chat: Voice Transcription | SenseAI
# Group chat: Petr & Alexander Coworking
# Group chat: Petr and Vitaly - Coworking
# Group chat: Petr and Lev - Coworking
# Group chat: Magic Leap Links
# Group chat: Федерация Боевых Мам
# Group chat: Petr & Mark, Danil
# Group chat: Hobbies: Movies
# Group chat: Shopping
# Group chat: Скайраннинг на эльбрус
# Group chat: Вечеринки на масловке - Орг 2.0
# Group chat: Координация по продуктам и питанию
# Group chat: Хобби: Горы, Альпинизм (Hobby, Hiking, Climbing)
# Group chat: Petr and Коля
# Group chat: Hobby Info - Бег, Runningmo
# Group chat: Нужно больше чатиков - 1
# Group chat: Petr & Даниэль, Danil
# Group chat: Работа в европке
# Group chat: Hobby Info - ...
# Group chat: Лавровы и Лоскутовы
# Group chat: Hobby Info - Велосипед
# Group chat: Hobby Info - вокал
# Group chat: Hobby Info - Плаванье
# Group chat: EF: Alexey/Petr, как научить жену тратить мои деньги
# Group chat: Триатлон в Швейцарии
# Group chat: Petr, Mark and Папа
# Group chat: Petr & Костя, Mark
# Group chat: Mark, Mitya and Petr
# Group chat: Petr & Александр, Mark
# Group chat: Petr & Mikhail, Ксения
# Group chat: Petr, Михаил and Mark
# Group chat: Petr & Mikhail, Вася
# Group chat: Zurich Программирование Мeetup 🤗
# Group chat: Petr, Николай and Елизавета
# Group chat: Лавровы и Марина
# Group chat: Tg bots
# Group chat: The Club: Notion Potion
# Group chat: OpenAI agentic research grant
# Group chat: Новый год 2024!
# Group chat: Дубай двойное ДР - Небоскреб-хата
# Group chat: Iris | Чат-менеджер, Иван и омагад редми
# Group chat: Cooking, Готовка
# Group chat: Petr, Никитина and Иван
# Group chat: "AA: Org"/Организицонные вопросы Петра Лаврова
# Group chat: Calmmage: BlogOrc
# Group chat: Content pipeline
# Group chat: Оплата с международных карт
# Group chat: (Яндекс) митап в Цюрихе
# Group chat: Дебаг транскрайбера
# Group chat: AA: Weekly Review, TeamLeading
# Group chat: Помощь Маме
# Group chat: ⚜️ AA: Design PM - Irina, Alisa
# Group chat: Petr & Иван, Vasily
# Group chat: Logseq Hackers
# Group chat: Paris Weekend 20.05.2023
# Group chat: Поступление в магу швейцарии
# Group chat: Petr & Pretty Please Bot
# Group chat: Задачки - Иван
# Group chat: AA - Рабочие задачи - Захар
# Group chat: Mikhail and Коля - Intro
# Group chat: AA: Assistance branding
# Group chat: Марк, Alexander - Intro
# Group chat: NY CH - Планируем Новый Год - Швейцария?
# Group chat: NY World - Планируем Новый Год - International?
# Group chat: NY Ru - Планируем Новый Год - Россия?
# Group chat: Mikhail and Георгий - Intro
# Group chat: Марк and Илья - Intro
# Group chat: Mikhail, Nikita
# Group chat: AA: Feed / Digest для Пети
# Group chat: Пробуем доверенное ассистенство - Миша, Роберт
# Group chat: Reviving Assistance - Ira
# Group chat: 0930 Путешествие в цюрих
# Group chat: Лавровы и Володя
# Group chat: Коммутативная группа
# Group chat: CM: Books & Reading
# Group chat: Пытаемся пойти на ЧГК
# Group chat: AA: Помощь с Notion
# Group chat: SBB Проверка Билетов
# Group chat: CM: Job Search. Resume advice, referrals
# Group chat: Операция «Танненбаум» - Мама и Дима едут в Цюрих
# Group chat: EF Interviews: Никита, Миша интро
# Group chat: EF Intro - Миша, Илья
# Group chat: Занятия для Степы и Феди
# Group chat: EF Intro - Федя, Миша
# Group chat: Учеба в США - информация для Роберта
# Group chat: EF Intro - Сеня, Миша
# Group chat: EF Intro - Марк, Костя
# Group chat: EF: пробуем кодить в open-source на Python
# Group chat: EF: Org
# Group chat: EF: Victor/Petr, допинать Петю ботать C++
# Group chat: EF: Mark/Petr, обновление EF
# Group chat: Petr and Anna
# Group chat: Family Space inbox
# Group chat: EF: Petr/Mikhail/Mark, групповые движухи
# Group chat: AA: Гайд про VR - 28 Jul 2023
# Group chat: AA: Гайд по организации сна - 28 Jul 2023
# Group chat: EF: Petr/Victor, как помогать и давать советы
# Group chat: EF: Petr/Mark, как сделать в EF Knowledge Base
# Group chat: AA: Chat with Victor takeaways - 25 Jul 2023
# Group chat: Кто быстрее - BTC
# Group chat: Занятия для Степы или Феди - Федя
# Group chat: CM: Org
# Group chat: AA: Org/process Ideas
# Group chat: EF: Mikhail/Petr, делаем планы для Марка без Марка
# Group chat: EF: Petr/Mark, short-term solution oriented therapy
# Group chat: CM: Music, Clips and Mood
# Group chat: Petr's Swiss Parties
# Group chat: Илья, Петя и Аня едут в трип
# Group chat: Лавровы и Ваня
# Group chat: Лавровы и Радзиминович
# Group chat: Лавровы и Косенковы
# Group chat: Лавровы и Гончаровы
# Group chat: Лавровы и Даша+Миша
# Group chat: Лавровы и Нанумян
# Group chat: В Гости в Лозанну
# Group chat: EF: Victor/Petr, прописать инвестиционную стратегию
# Group chat: Assistance 2022
# Group chat: Леша Кудринский Ассистентство Петя Лавров
# Group chat: [Archive] Assistance 2022
# Group chat: EF: Petr/Mark, как делать то, что запланировал на прошлых сессиях
# Group chat: Client Developement for ChatGPT/LLM
# Group chat: SwissСовет
# Group chat: 🇷🇺🇨🇭🇹🇷 Nastya, Ali & Anna, Petr
# Group chat: CM: Sport & Food Order
# Group chat: CM: AI Tools
# Group chat: CM: Celebrating Toxicity
# Group chat: CM: Feed & Reposts
# Group chat: CM: Dev
# Group chat: CM: Gaming
# Group chat: CM: Shopping
# Group chat: CM: Health / Productivity
# Group chat: CM: Душним Петю
# Group chat: CM: CalmMage Chat - флудилка
# Group chat: CM: GPT Dev
# Group chat: CM: Math & Love
# Group chat: Лавровы и Лысенко
# Group chat: Лавровы и Витечка
# Group chat: Лавровы / Глушенковы-Карцевы
# Group chat: Лавровы и Фецы
# Group chat: Лавровы и Леша
# Group chat: Лавровы + Паша
# Group chat: Лавровы и Кудринские-Орловы
# Group chat: Лавровы и Федя
# Group chat: Лавровы и Некрасовы Family
# Group chat: Лавровы и Жаркевич(и?) :)
# Group chat: Лавровы и Nicola
# Group chat: Лавровы и Миша
# Group chat: Лавровы и Кремер
# Group chat: Лавровы и Паша
# Group chat: EF: Petr/Mikhail, разговор со стартапом о деньгах
# Group chat: EF: Petr/Andrew, бады, допинги, стимуляторы, вещества
# Group chat: GPT Chat
# Group chat: Дележка вещей
# Group chat: [Архив] Орг - Йога Турция июнь 2023
# Group chat: Йога интенсив Октябрь 2023, Каш, Турция - Общий чатик
# Group chat: Орг чат - Йога интенсив Октябрь 2023, Каш, Турция
# Group chat: EF: Mark/Petr, проблемы с коленкой
# Group chat: Engineering Friends
# Group chat: IBS -вебинар Chat GPT
# Group chat: Разбираемся со слизью
# Group chat: Swiss Kiss
# Group chat: Марк, Коля, Канада
# Group chat: [Archive] Хайкинг (нет)
# Group chat: [Archive]Йога Крым 09.21
# Group chat: Лавровы и Козловы
# Group chat: ChatSummary Bot Feedback
# Group chat: EF: Victor/Petr, польза ChatGPT в жизни
# Group chat: EF: Petr/Mark, бот-ассистент
# Group chat: EF: Petr/Mikhail, чат саммари бот
# Group chat: EF: Petr/Alexander, найти ментора
# Group chat: Интенсив Йога Баку 2023
# Group chat: Летняя йога ☀️🦭
# Group chat: EF: ⚙️ Petr/: AI тулзы
# Group chat: Petr Lavrov Feedback
# Group chat: EF: Petr/Mark, парный кодинг
# Group chat: Команда "А"
# Group chat: Petr & Pavel Volichenko, Николай
# Group chat: Ви25
# Group chat: Advanced Python Course Mar 2023
# Group chat: Petr & Valentin, Mikhail
# Group chat: Немного про образование
# Group chat: [Fusion Lab] Gpt Integration ideas
# Group chat: В гости к Фецам
# Group chat: Money Making Marathon
# Group chat: Феррари парк без папы
# Group chat: Регатата
# Group chat: Биздев - Intro Иван-Юра
# Group chat: Швейцария. Экономические игры
# Group chat: Discarded
# Group chat: Развлекайтесь
# Group chat: Внедряй AI
# Group chat: Intro Рустам Илья - Neuro
# Group chat: Стендап 3 февраля
# Group chat: Ai Feedback
# Group chat: Путевые заметки друзей
# Group chat: 🧠Memory Games
# Group chat: Команда Кольца всевластия
# Group chat: У Марины завтра др =)
# Group chat: Петя, Аня, Костя и Женя
# Group chat: Вечеринка кредиторов
# Group chat: 📋Task Management
# Group chat: Petr & Rustam. B2B nocode gpt pipelines, gpt consulting
# Group chat: Petr & Pavel, GPT Assistant - teach GPT to use database, backend, scenarios
# Group chat: 166 Swiss - Бытовое (Ваня, Петя, Аня)
# Group chat: Турагентство "Paradise in Exile"
# Group chat: Организация ДР Пети и Феди 2023
# Group chat: Articles, Publishing marterial
# Group chat: Петя, Аня и Арина, Миша
# Group chat: Мы летим в Египет!
# Group chat: Меню НГ 2023
# Group chat: GPT Usecases
# Group chat: Паша, Аня и Петя
# Group chat: ДР Пети и Феди, Дубай, 18-19 Фев 2023
# Group chat: Готовимся к НГ! 🎄🎉
# Group chat: Russia НГ Tussa
# Group chat: Global Information chat
# Group chat: Petr & Марина Startup
# Group chat: Лыжи к нам поближе
# Group chat: Нейронки Telega
# Group chat: Python обучение - Роберт, Петя, Лева
# Group chat: Интенсив Йога Египет 2022
# Group chat: Жюри/проверяющие для хакатона
# Group chat: Лыжные Делишки
# Group chat: Упражнение по составлению фриланс контракта
# Group chat: Петя/Сима
# Group chat: Petr & Ramil, Марк
# Group chat: Секретный чат Вотякова
# Group chat: Петя и Аня, мама
# Group chat: Test
# Group chat: Run Лёва Run
# Group chat: Голосовые записи
# Group chat: Voice memos
# Group chat: ЧГК Google (Switzerland?)
# Group chat: Интенсив Йога Каш 2022
# Group chat: Бостон-Цюрих-Турцияяя
# Group chat: Wednesday lunch / Zurich
# Group chat: Организация йога-интенсива Каш Ноябрь 2022
# Group chat: Мск 2021/12
# Group chat: Inbox
# Group chat: Я соскучился (Гоша, Аня и Петя)
# Group chat: Feed
# Group chat: Referral
# Group chat: Саша Миша - как искать работу
# Group chat: Байки про работу
# Group chat: Опять он приехал
# Group chat: We married!
# Group chat: Саша Ксюша интро
# Group chat: Отпуск 2022 планирование
# Group chat: FRM - Управление дружбой
# Group chat: Archive
# Group chat: Food Order
# Group chat: Лёва едет в Цюрих
# Group chat: Books
# Group chat: Фец зовет в гости
# Group chat: Petr's Parties
# Group chat: Zurich: Home and something
# Group chat: Outstanding items.
# Group chat: Альпы 2020 08.02-10.02
# Group chat: Redirect to Reading!!!
# Group chat: Мета-чат № 109059
# Group chat: Саша Андрей скрипт :)
# Group chat: Ваня, Саша - Поиск работы
# Group chat: Коучинг Дима Лева
# Group chat: Надя Миша Покер DS
# Group chat: Петя и Аня
# Group chat: Ideas and todos March 2022
# Group chat: Ирина Ассистентство
# Group chat: 1630
# Group chat: 146: встреча 22.02.2022 мск
# Group chat: Подарки друзьям
# Group chat: Мини-Макс Свадьба-Афтерпати 21.02.2022. Ваня и Иришка.
# Group chat: Коучинг: Марк/Петя
# Group chat: Свадьба 13.02.2022. Иван + Ирина. Чат друзей.
# Group chat: Петин чатик
# Group chat: The Club: Founders
# Group chat: Family Coffee
# Group chat: Баня мытищи
# Group chat: Party 22.01.2022
# Group chat: The Club Coffee
# Group chat: DND 23 Jan, 1 master + 5 players
# Group chat: Мини-туса 27
# Group chat: 17 июля. Мальчишник не в вегасе
# Group chat: The Club Forum Organization
# Group chat: Кв 67
# Group chat: 26.12.21. New Year Party. Exclusive.
# Group chat: Подарок на Др Иришки
# Group chat: HPA: Общий чат
# Group chat: Петр Задачки. HPA
# Group chat: Notion Development
# Group chat: VR Intro
# Group chat: HPA: Org
# Group chat: Ламповый некогда ВорлдКвант
# Group chat: The Club: Legal, Tax & Accounting
# Group chat: КастДев Коля
# Group chat: HPA.Команда Пети.Общий чат.
# Group chat: Aibek Danya intro
# Group chat: The Club: PartOrg — Parties
# Group chat: КастДев Федя
# Group chat: КастДев Надя
# Group chat: КастДев Саша
# Group chat: 146 Аня Петя
# Group chat: The Club Org
# Group chat: 146: Математика от Леонида Попова
# Group chat: The Club Design
# Group chat: 146. Проработка возражений учителей перед стратсессией
# Group chat: Я тоже скидывался. Крым
# Group chat: 146: программа развития
# Group chat: Обсуждение канала "Переполох на ровном месте"
# Group chat: Sunny Senya intro
# Group chat: Ваня Миша интро
# Group chat: Свадьба 18
# Group chat: 146: Aydarov, Istomin, Lavrov
# Group chat: Никола-Ленивец
# Group chat: Ленин и дети.
# Group chat: Организация большой свадьбы
# Group chat: Квартира 166. Быт
# Group chat: Party Coctails Guru
# Group chat: Книжки
# Group chat: 146: Analytics.Junior
# Group chat: Notion Potion
# Group chat: Feedback
# Group chat: Petr
# Group chat: Piter Parties
# Group chat: TeamLead Club
# Group chat: Театр
# Group chat: Power Girls 146
# Group chat: Онбоардинг Ярослав
# Group chat: Чемодан Ксении
# Group chat: 146: база данных
# Group chat: Ноутбук для Кирилла
# Group chat: 146. Встреча выпускников
# Group chat: Luxoft Onboarding
# Group chat: Exclusive party 25.04
# Group chat: Витя 27
# Group chat: Турция 2021
# Group chat: Программирование
# Group chat: Лето серфинг 2021
# Group chat: Клуб 27
# Group chat: 146: воркшопы
# Group chat: Senya Vanya intro
# Group chat: Операционная поддержка
# Group chat: 146: 28 Feb GrowUp Coworking
# Group chat: 146: волонтеры
# Group chat: Поиск работы
# Group chat: Раздел трофеев
# Group chat: 146: план подготовки стратсесии
# Group chat: Добавление к Asana
# Group chat: День Рождения Пети и Феди
# Group chat: Ирония судьбы, или ария московского гостя
# Group chat: 146: Организация 28 Февраля
# Group chat: Сорочаны среда 03 фев
# Group chat: 146: Встреча 28 Февраля
# Group chat: 146: Интернет-магазин мерча
# Group chat: 146: Analytics
# Group chat: Конкурс для школьников
# Group chat: Alla Misha intro
# Group chat: Рабочая группа 146, Новый набор
# Group chat: Домашнее задание 24 янв, координация
# Group chat: 146 - Организаторы
# Group chat: Подготовка к региону по информатике
# Group chat: Факультатив по программированию
# Group chat: Intro Petr Alex
# Group chat: Intro Petr/Vladimir
# Group chat: Затусите в Шерегеше?
# Group chat: Витя в больничке
# Group chat: ДР Масальцева
# Group chat: Patty Party
# Group chat: ДР Феца 23 октября
# Group chat: ДР Масальцева
# Group chat: Депо ивнинг
# Group chat: Petr + Denis
# Group chat: Встреча выпускников
# Group chat: Петины вечеринки
# Group chat: 11в 2010 146
# Group chat: Математические интро
# Group chat: Влад достал рождаться
# Group chat: Тусим
# Group chat: День независимости
# Group chat: Камчатка (20 - 30 июля)
# Group chat: Обсуждение автоматизации ответов на популярные вопросы в образовании
# Group chat: Изолированная прогулка
# Group chat: Adult Software Development
# Group chat: Флуд на йоге
# Group chat: Travel weekends
# Group chat: Двойное обязательство
# Group chat: Деловые сосиски
# Group chat: Вечеринка у меня дома
# Group chat: Австрия Альпы 2020
# Group chat: Экспромтовские новости
# Group chat: Winx Club (я и блогеры-друзья)
# Group chat: ДР Феца 26 октября
# Group chat: Гонка героев 10.08/11.08
# Group chat: [Travel Trip] Спб 2019-03
# Group chat: Frisbee Y
# Group chat: Катя хочет вас видеть, вы Катю - как повезет..:)
# Group chat: Движуха тебе в ухо
# Group chat: Noize
# Group chat: 27 октября др феца
# Group chat: Noize MC 24 ноября
# Group chat: [Travel Trip] Екб 2018-10
# Group chat: 29/30 09 2018
# Group chat: Я.Квест 81
# Group chat: WQ Выпуск
# Group chat: Движ
# Group chat: Работяги
# Group chat: Жирафики...
# Group chat: Теннис
# Group chat: QTB
# Group chat: Однодневные проекты
# Group chat: QTB Transition
# Group chat: Игрушечки :)

# %%
# Fixed categorization
def is_true_channel(chat):
    return chat.is_channel and not chat.is_group


# Basic counts
private_chats = [c for c in chats if c.is_user and not getattr(c.entity, 'bot', False)]
groups = [c for c in chats if c.is_group]  # Keep this as is
channels = [c for c in chats if is_true_channel(c)]  # Only true channels
bots = [c for c in chats if c.is_user and getattr(c.entity, 'bot', True)]

# Ownership counts
owned_groups = [c for c in groups if get_creator(c)]
owned_channels = [c for c in channels if get_creator(c)]


def get_stats_message():
    stats_message = "Chat Statistics:\n"

    stats_message += f"Private chats: {len(private_chats)}\n"

    stats_message += f"\nGroups: {len(groups)}\n"
    stats_message += f"  - owned: {len(owned_groups)}\n"

    stats_message += f"\nChannels: {len(channels)}\n"
    stats_message += f"  - owned: {len(owned_channels)}\n"

    stats_message += f"\nBots: {len(bots)}\n"

    # Verification
    total = len(private_chats) + len(groups) + len(channels) + len(bots)
    stats_message += f"\nTotal chats: {len(chats)}\n"
    stats_message += f"Sum of categories: {total}\n"
    stats_message += f"Difference: {len(chats) - total}\n"

    return stats_message


print(get_stats_message())
# Out:
# Chat Statistics:
# Private chats: 732
#
# Groups: 821
#   - owned: 512
#
# Channels: 127
#   - owned: 33
#
# Bots: 99
#
# Total chats: 1779
# Sum of categories: 1779
# Difference: 0

# %%
from random import choice
from datetime import datetime


def get_basic_chat_stats(chat):
    stats = {
        "title": chat.title,
        "last_message_date": chat.date,
        "creation_date": getattr(chat.entity, 'date', None),
        "participants_count": getattr(chat.entity, 'participants_count', None),
    }
    return stats


# Sample from each category and show stats
print("=== Random Samples ===")

# Private chat
if private_chats:
    sample = choice(private_chats)
    print("\nPrivate Chat Sample:")
    stats = get_basic_chat_stats(sample)
    print(f"Title: {stats['title']}")
    print(f"Last message: {stats['last_message_date']}")
    print(f"Added: {stats['creation_date']}")
    # We might need to use client.get_entity() to get more user details

# Group
if groups:
    sample = choice(groups)
    print("\nGroup Sample:")
    stats = get_basic_chat_stats(sample)
    print(f"Title: {stats['title']}")
    print(f"Members: {stats['participants_count']}")
    print(f"Last message: {stats['last_message_date']}")
    print(f"Added: {stats['creation_date']}")
    # print(f"Is megagroup: {sample.entity.megagroup}")

# Channel
if channels:
    sample = choice(channels)
    print("\nChannel Sample:")
    stats = get_basic_chat_stats(sample)
    print(f"Title: {stats['title']}")
    print(f"Subscribers: {stats['participants_count']}")
    print(f"Last message: {stats['last_message_date']}")
    print(f"Added: {stats['creation_date']}")
    print(f"Broadcast: {sample.entity.broadcast}")

# Size distribution
print("\n=== Size Statistics ===")
big_groups = [g for g in groups if getattr(g.entity, 'participants_count', 0) > 1000]
big_channels = [c for c in channels if
                getattr(c.entity, 'participants_count', 0) > 1000]

print(f"Big groups (>1000): {len(big_groups)} out of {len(groups)}")
print(f"Big channels (>1000): {len(big_channels)} out of {len(channels)}")
# Out:
# === Random Samples ===
#
# Private Chat Sample:
# Title: Sergey Morozov
# Last message: 2019-05-22 08:14:19+00:00
# Added: None
#
# Group Sample:
# Title: День независимости
# Members: 7
# Last message: 2020-07-05 16:40:30+00:00
# Added: 2020-07-02 10:27:31+00:00
#
# Channel Sample:
# Title: Лев Лавров 🦁
# Subscribers: 116
# Last message: 2024-09-19 19:26:01+00:00
# Added: 2022-03-13 11:56:35+00:00
# Broadcast: True
#
# === Size Statistics ===
# Big groups (>1000): 5 out of 821
# Big channels (>1000): 57 out of 127

# %%
def plot_size_distribution(items, title):
    sizes = [getattr(item.entity, 'participants_count', 0) for item in items]
    max_size = max(sizes)

    # Custom bin edges for more intuitive intervals
    bins = [
        1, 3, 10, 30, 100, 300,  # Small groups/channels
        1000, 3000, 10000,  # Medium
        30000, 100000,  # Large
        300000, 1000000  # Huge
    ]

    # Filter out empty upper bins
    while bins[-1] > max_size * 1.1:  # Keep one empty bin for visual clarity
        bins.pop()

    plt.figure(figsize=(12, 6))

    # Calculate histogram data
    counts, edges = np.histogram(sizes, bins=bins)

    # Plot bars manually with fixed width in log space
    bar_width = 0.8  # Width in log space
    log_edges = np.log10(edges[:-1])

    plt.bar(edges[:-1], counts,
            width=[edge * bar_width for edge in edges[:-1]],
            # Width proportional to x position
            align='center')

    plt.xscale('log')

    # Create interval labels
    labels = [f'{bins[i]:,}-{bins[i + 1]:,}' for i in range(len(bins) - 1)]
    plt.xticks(bins[:-1], labels, rotation=45, ha='right')

    # Add value labels on top of bars
    for i, count in enumerate(counts):
        if count > 0:  # Only label non-empty bars
            plt.text(edges[i], count, f'{int(count)}',
                     va='bottom', ha='center')

    plt.title(f'{title} Size Distribution (n={len(items)})')
    plt.xlabel('Number of participants')
    plt.ylabel('Count')

    # Add grid for better readability
    plt.grid(True, alpha=0.3)

    # Adjust layout to prevent label cutoff
    plt.tight_layout()

    plt.show()

    # Print statistics
    print(f"\n{title} size statistics:")
    print(f"Median size: {np.median(sizes):,.0f}")
    print(f"Mean size: {np.mean(sizes):,.0f}")
    print(f"Max size: {max_size:,}")


# Plot distributions
plot_size_distribution(groups, 'Groups')
plot_size_distribution(channels, 'Channels')
# Out:
# Groups size statistics:
# Median size: 3
# Mean size: 48
# Max size: 11,511
# Channels size statistics:
# Median size: 239
# Mean size: 195,746
# Max size: 13,054,639

# %%
def plot_small_size_distribution(items, title):
    sizes = [getattr(item.entity, 'participants_count', 0) for item in items]

    # Custom bin edges for small groups
    bins = list(range(1, 12))  # 1 to 11 to capture sizes 1-10

    plt.figure(figsize=(10, 6))

    # Calculate histogram data
    counts, edges = np.histogram(sizes, bins=bins)

    # Plot bars
    plt.bar(range(1, 11), counts, width=0.7, align='center')

    # Set x-axis ticks to whole numbers
    plt.xticks(range(1, 11))

    # Add value labels on top of bars
    for i, count in enumerate(counts):
        if count > 0:  # Only label non-empty bars
            plt.text(i + 1, count, f'{int(count)}',
                     va='bottom', ha='center')

    plt.title(f'{title} Size Distribution (1-10 members, n={sum(counts)})')
    plt.xlabel('Number of participants')
    plt.ylabel('Count')

    # Add grid for better readability
    plt.grid(True, alpha=0.3)

    # Adjust layout
    plt.tight_layout()

    plt.show()


# Plot distributions
plot_small_size_distribution(groups, 'Groups')
plot_small_size_distribution(channels, 'Channels')

# %%
chat = chats[0]

# for attr in dir(chat):
#     if not attr.startswith('_'):  # Skip private attributes
#         print(f"{attr}: {getattr(chat, attr)}")

data = chat.entity.to_json()
data
# Out:
# '{"_": "Channel", "id": 2373457856, "title": "CalmMage Daily Meditation", "photo": {"_": "ChatPhoto", "photo_id": 5221936468610636825, "dc_id": 2, "has_video": false, "stripped_thumb": "AQgIpbV+z54ooopgfw=="}, "date": "2024-10-07T06:39:16+00:00", "creator": true, "left": false, "broadcast": false, "verified": false, "megagroup": true, "restricted": false, "signatures": false, "min": false, "scam": false, "has_link": false, "has_geo": false, "slowmode_enabled": false, "call_active": false, "call_not_empty": false, "fake": false, "gigagroup": false, "noforwards": false, "join_to_send": false, "join_request": false, "forum": false, "stories_hidden": false, "stories_hidden_min": false, "stories_unavailable": true, "signature_profiles": false, "access_hash": 8371095179012486494, "username": null, "restriction_reason": [], "admin_rights": {"_": "ChatAdminRights", "change_info": true, "post_messages": true, "edit_messages": true, "delete_messages": true, "ban_users": true, "invite_users": true, "pin_messages": true, "add_admins": true, "anonymous": false, "manage_call": true, "other": true, "manage_topics": true, "post_stories": true, "edit_stories": true, "delete_stories": true}, "banned_rights": null, "default_banned_rights": {"_": "ChatBannedRights", "until_date": "2038-01-19T03:14:07+00:00", "view_messages": false, "send_messages": false, "send_media": false, "send_stickers": false, "send_gifs": false, "send_games": false, "send_inline": false, "embed_links": false, "send_polls": false, "change_info": false, "invite_users": false, "pin_messages": false, "manage_topics": false, "send_photos": false, "send_videos": false, "send_roundvideos": false, "send_audios": false, "send_voices": false, "send_docs": false, "send_plain": false}, "participants_count": 6, "usernames": [], "stories_max_id": null, "color": null, "profile_color": null, "emoji_status": null, "level": null, "subscription_until_date": null}'

# %%
from telethon.tl.types import Channel, Chat, User

# Let's analyze one chat
chat = chats[0]

print("=== Dialog attributes we use ===")
print(f"is_user: {chat.is_user}")
print(f"is_group: {chat.is_group}")
print(f"is_channel: {chat.is_channel}")

print("\n=== Entity equivalent checks ===")
entity = chat.entity
print(f"is_user: {isinstance(entity, User)}")
print(f"is_group: {isinstance(entity, Chat)}")
print(f"is_channel: {isinstance(entity, Channel)}")
print(
    f"is_channel but not megagroup: {isinstance(entity, Channel) and not entity.megagroup}")


# Let's try to rewrite our categorization using only entities
def categorize_entity(entity):
    if isinstance(entity, User):
        return 'private' if not getattr(entity, 'bot', False) else 'bot'
    elif isinstance(entity, Chat):
        return 'group'
    elif isinstance(entity, Channel):
        return 'channel' if not entity.megagroup else 'group'
    return 'unknown'


# Test the new categorization
print("\n=== Testing new categorization ===")
categories = {}
for chat in chats:  # Test first 5 chats
    old_cat = 'private' if chat.is_user else 'group' if chat.is_group else 'channel'
    new_cat = categorize_entity(chat.entity)
    if old_cat != new_cat:
        # print(f"Mismatch: {old_cat} vs {new_cat} for {chat.entity.title}")
        print(f"Mismatch: {old_cat} vs {new_cat}")
    # else:
    #     print(f"Match: {old_cat} vs {new_cat} for {chat.entity.title}")
# Out:
# === Dialog attributes we use ===
# is_user: False
# is_group: True
# is_channel: True
#
# === Entity equivalent checks ===
# is_user: False
# is_group: False
# is_channel: True
# is_channel but not megagroup: False
#
# === Testing new categorization ===
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: group vs unknown
# Mismatch: private vs bot
# Mismatch: private vs bot
# Mismatch: private vs bot

# %%
# Let's analyze one chat
chat = chats[0]

print("=== Dialog vs Entity categorization ===")


# Original Dialog-based categorization
def categorize_dialog(chat):
    if chat.is_user:
        return 'bot' if getattr(chat.entity, 'bot', False) else 'private'
    elif chat.is_group:
        return 'group'
    elif chat.is_channel:
        return 'channel'
    return 'unknown'


# New Entity-based categorization
def categorize_entity(entity):
    if isinstance(entity, User):
        return 'bot' if getattr(entity, 'bot', False) else 'private'
    elif isinstance(entity, Chat):
        return 'group'
    elif isinstance(entity, Channel):
        return 'channel' if not entity.megagroup else 'group'
    return 'unknown'


# Test the categorizations
print("\n=== Testing categorization (first 5 chats) ===")
for chat in chats[:5]:
    old_cat = categorize_dialog(chat)
    new_cat = categorize_entity(chat.entity)
    print(f"Title: {chat.entity.title}")
    print(f"Dialog cat: {old_cat}")
    print(f"Entity cat: {new_cat}")
    print()

# Count all categories
dialog_cats = {}
entity_cats = {}

for chat in chats:
    d_cat = categorize_dialog(chat)
    e_cat = categorize_entity(chat.entity)

    if d_cat != e_cat:
        print(f"Mismatch: {d_cat} vs {e_cat} for {chat.entity.title}")
        res = chat

    dialog_cats[d_cat] = dialog_cats.get(d_cat, 0) + 1
    entity_cats[e_cat] = entity_cats.get(e_cat, 0) + 1

print("=== Total counts ===")
print("Dialog categorization:", dialog_cats)
print("Entity categorization:", entity_cats)
# Out:
# === Dialog vs Entity categorization ===
#
# === Testing categorization (first 5 chats) ===
# Title: CalmMage Daily Meditation
# Dialog cat: group
# Entity cat: group
#
# Title: EF Once-a-week Challenges
# Dialog cat: group
# Entity cat: group
#
# Title: Интересные мысли (без репостов)
# Dialog cat: group
# Entity cat: group
#
# Title: CalmMage Raw (ex. Daily)
# Dialog cat: channel
# Entity cat: channel
#
# Title: CalmMage Life
# Dialog cat: channel
# Entity cat: channel
#
# Mismatch: group vs unknown for Австрия Альпы 2020
# === Total counts ===
# Dialog categorization: {'group': 821, 'channel': 127, 'private': 732, 'bot': 99}
# Entity categorization: {'group': 820, 'channel': 127, 'private': 732, 'bot': 99, 'unknown': 1}

# %%
res.__dict__
# Out:
# {'_client': <telethon.client.telegramclient.TelegramClient at 0x11a65fc90>,
#  'dialog': <telethon.tl.types.Dialog at 0x11c655690>,
#  'pinned': False,
#  'folder_id': None,
#  'archived': False,
#  'message': <telethon.tl.patched.MessageService at 0x11c6634d0>,
#  'date': datetime.datetime(2019, 11, 29, 7, 16, 15, tzinfo=datetime.timezone.utc),
#  'entity': <telethon.tl.types.ChatForbidden at 0x11c674c90>,
#  'input_entity': <telethon.tl.types.InputPeerChat at 0x11c697050>,
#  'id': -313928939,
#  'name': 'Австрия Альпы 2020',
#  'title': 'Австрия Альпы 2020',
#  'unread_count': 0,
#  'unread_mentions_count': 0,
#  'draft': <telethon.tl.custom.draft.Draft at 0x11c6970d0>,
#  'is_user': False,
#  'is_group': True,
#  'is_channel': False}

# %%
res.entity.to_json()
# Out:
# '{"_": "ChatForbidden", "id": 313928939, "title": "\\u0410\\u0432\\u0441\\u0442\\u0440\\u0438\\u044f \\u0410\\u043b\\u044c\\u043f\\u044b 2020"}'

# %%
# Plan:
# 1 - general get_chats
# 2 - _get_chats_from_disk
# 3 - _get_chats_from_client
# 4 - _has_fresh_chats_on_disk

# %%
from datetime import timedelta
from datetime import datetime
from pathlib import Path
import json

type_map = {
    'Channel': Channel,
    'Chat': Chat,
    'User': User
}


def _get_chats_from_disk():
    data_path = Path("data/chats.json")

    data = json.loads(data_path.read_text())
    chats = [
        type_map[entity['type']].from_json(entity['data'])
        for entity in data['entities']
    ]
    return chats


async def get_chat_list() -> List[Dialog]:
    client = await get_telethon_client()
    chats = await client.get_dialogs()
    return chats


def _get_chats_from_client():
    # Store chats in memory
    chats = asyncio.run(get_chat_list())
    return [chat.entity for chat in chats]


def _has_fresh_chats_on_disk():
    data_path = Path("data/chats.json")

    if not data_path.exists():
        return False

    data = json.loads(data_path.read_text())
    timestamp = data['timestamp']
    return datetime.now() - datetime.fromisoformat(timestamp) < timedelta(days=1)


from datetime import datetime


def _save_chats_to_disk(chats):
    data = {
        'entities': {
            'type': str(type(chat)),
            'data': chat.to_json()
        },
        'timestamp': datetime.now().isoformat()
    }

    data_path = Path("data/chats.json")
    data_path.parent.mkdir(exist_ok=True)
    data_path.write_text(json.dumps(data))


def get_chats():
    if _has_fresh_chats_on_disk():
        return _get_chats_from_disk()
    else:
        chats = _get_chats_from_client()
        _save_chats_to_disk(chats)
        return chats

# %%
# save chats to disk
# test step 1
chats = _get_chats_from_client()
# Out:
# 2024-12-30 03:01:05.710 | DEBUG    | telethon_manager:__init__:24 - TelethonManager initialized with storage_mode: StorageMode.TO_DISK
# 2024-12-30 03:01:05.711 | DEBUG    | telethon_manager:__init__:25 - TelethonManager initialized with sessions dir: sessions
# 2024-12-30 03:01:05.711 | DEBUG    | telethon_manager:get_telethon_client:28 - Getting telethon client for user 291560340 with storage mode StorageMode.TO_DISK
# 2024-12-30 03:01:05.711 | DEBUG    | telethon_manager:_get_telethon_client_from_disk:36 - Attempting to get telethon client from disk for user 291560340
# 2024-12-30 03:01:05.712 | DEBUG    | telethon_manager:_check_if_conn_is_present_on_disk:115 - Checking if session file exists for user 291560340: True
# 2024-12-30 03:01:05.712 | DEBUG    | telethon_manager:_get_telethon_client_from_disk:38 - Found existing connection on disk for user 291560340
# 2024-12-30 03:01:05.712 | DEBUG    | telethon_manager:_load_conn_from_disk:122 - Loading session for user 291560340 from sessions/user_291560340.session
# 2024-12-30 03:01:05.714 | DEBUG    | telethon_manager:_load_conn_from_disk:130 - Attempting to connect existing client for user 291560340
# 2024-12-30 03:01:05.867 | DEBUG    | telethon_manager:_load_conn_from_disk:134 - Session authorization check for user 291560340: True
# 2024-12-30 03:01:05.868 | DEBUG    | telethon_manager:_load_conn_from_disk:138 - Successfully loaded and authorized client for user 291560340
# Task was destroyed but it is pending!
# task: <Task pending name='Task-412' coro=<Connection._send_loop() running at /Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/network/connection/connection.py:322> wait_for=<Future pending cb=[Task.__wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-413' coro=<Connection._recv_loop() running at /Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/network/connection/connection.py:341> wait_for=<Future pending cb=[Task.__wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-414' coro=<MTProtoSender._send_loop() running at /Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/network/mtprotosender.py:464> wait_for=<Future pending cb=[Task.__wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-415' coro=<MTProtoSender._recv_loop() running at /Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/network/mtprotosender.py:507> wait_for=<Future pending cb=[Task.__wakeup()]>>
# Exception ignored in: <coroutine object Connection._recv_loop at 0x157d4ae30>
# Traceback (most recent call last):
#   File "/Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/extensions/binaryreader.py", line 37, in read_int
#     return int.from_bytes(self.read(4), byteorder='little', signed=signed)
#            ^^^^^^^^^^^^^^
# RuntimeError: coroutine ignored GeneratorExit
# Server closed the connection: [Errno 54] Connection reset by peer
# Server resent the older message 7454005538028324865, ignoring
# Cannot get difference since the account is likely misusing the session: attempt to write a readonly database
# Unhandled exception from keepalive_handle after cancelling <class 'asyncio.tasks.Task'> (<Task finished name='Task-424' coro=<UpdateMethods._keepalive_loop() done, defined at /Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/client/updates.py:481> exception=OperationalError('disk I/O error')>)
# Traceback (most recent call last):
#   File "/Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/helpers.py", line 176, in _cancel
#     await task
#   File "/nix/store/cgc094j7jm0dm4xj0v1hy4361pji4ys6-python3-3.11.10/lib/python3.11/asyncio/futures.py", line 290, in __await__
#     return self.result()  # May raise too.
#            ^^^^^^^^^^^^^
#   File "/nix/store/cgc094j7jm0dm4xj0v1hy4361pji4ys6-python3-3.11.10/lib/python3.11/asyncio/futures.py", line 203, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/nix/store/cgc094j7jm0dm4xj0v1hy4361pji4ys6-python3-3.11.10/lib/python3.11/asyncio/tasks.py", line 277, in __step
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "/Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/client/updates.py", line 519, in _keepalive_loop
#     self.session.save()
#   File "/Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/sessions/sqlite.py", line 237, in save
#     self._conn.commit()
# sqlite3.OperationalError: disk I/O error

# %%
from pathlib import Path
import json

data_path = Path("data/chats.json")
data = json.loads(data_path.read_text())

# chats = [type_map[entity['type']](entity['data']) for entity in data['entities']]

# %%
x = data['entities'][0]
t = type_map[x['type']]
d = json.loads(x['data'])
new_d = {
    'timestamp': data['timestamp'],
    'entities': [
        chat['data'] for chat in data['entities']
    ]
}
json.dump(new_d, open("data/chats.json", "w"), indent=2)

# %%
for i in data['entities']:
    d = json.loads(i['data'])
    if "_" not in d:
        print(d)
    print(d['_'])
# Out:
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# User
# User
# User
# Channel
# Channel
# Channel
# Channel
# Chat
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# User
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Chat
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# User
# Channel
# Channel
# Channel
# Chat
# Chat
# Channel
# User
# User
# Channel
# Channel
# Channel
# Channel
# User
# Channel
# Chat
# Channel
# Channel
# Channel
# Channel
# Channel
# User
# User
# Channel
# Channel
# User
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# User
# Channel
# Channel
# Channel
# Channel
# User
# User
# User
# Channel
# User
# Channel
# User
# User
# Channel
# User
# Channel
# Channel
# User
# User
# Channel
# Channel
# Channel
# Channel
# User
# User
# User
# Channel
# Channel
# Channel
# Channel
# User
# Channel
# Channel
# User
# Channel
# Channel
# Chat
# Channel
# Channel
# Channel
# Channel
# Channel
# Chat
# User
# Chat
# Channel
# Channel
# Channel
# Channel
# User
# Chat
# Channel
# Channel
# Chat
# Chat
# Channel
# Channel
# User
# User
# User
# Channel
# Channel
# User
# Channel
# Channel
# Chat
# User
# Channel
# Chat
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# Channel
# User
# User
# Channel
# User
# Channel
# User
# User
# Channel
# Chat
# User
# User
# Channel
# Channel
# User
# Channel
# Channel
# Channel
# User
# User
# Channel
# User
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# Channel
# Channel
# User
# Channel
# User
# User
# Channel
# Chat
# Channel
# Channel
# Channel
# Channel
# Chat
# Channel
# Channel
# Channel
# Chat
# User
# Channel
# Channel
# User
# Channel
# Channel
# Channel
# User
# User
# User
# Chat
# Channel
# Chat
# Channel
# Channel
# User
# User
# Channel
# User
# Channel
# Channel
# Channel
# User
# User
# User
# User
# Channel
# User
# Chat
# User
# User
# User
# Chat
# User
# User
# User
# Channel
# Chat
# Chat
# Channel
# User
# User
# Channel
# Chat
# User
# Channel
# User
# Channel
# Channel
# Channel
# Channel
# User
# Channel
# Channel
# User
# User
# User
# Channel
# User
# Channel
# User
# Chat
# Channel
# Chat
# User
# User
# User
# Chat
# Channel
# Channel
# Channel
# Channel
# User
# Channel
# Channel
# Channel
# User
# User
# User
# User
# Channel
# Chat
# Channel
# Channel
# Channel
# Chat
# Channel
# Channel
# User
# User
# User
# Channel
# Chat
# Channel
# Chat
# User
# Channel
# Channel
# Channel
# Channel
# User
# User
# User
# Channel
# User
# Chat
# User
# Channel
# Chat
# User
# User
# Channel
# User
# User
# User
# Channel
# User
# User
# Chat
# Channel
# User
# User
# User
# User
# Chat
# User
# User
# User
# Channel
# Chat
# User
# User
# Chat
# Chat
# User
# User
# Channel
# Chat
# User
# Channel
# Chat
# User
# Chat
# Chat
# Channel
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# User
# Channel
# Channel
# Chat
# Channel
# User
# Chat
# User
# User
# Channel
# User
# Channel
# User
# User
# User
# Chat
# User
# Chat
# Chat
# Channel
# User
# Chat
# Channel
# User
# User
# User
# User
# Channel
# User
# Channel
# User
# Chat
# Chat
# Channel
# Channel
# Chat
# User
# User
# Channel
# Channel
# User
# Chat
# Channel
# Chat
# Channel
# Channel
# Channel
# Channel
# User
# Channel
# Chat
# User
# Channel
# User
# Channel
# Channel
# Chat
# User
# Chat
# Channel
# Channel
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Channel
# Channel
# Chat
# Channel
# User
# Channel
# Chat
# User
# Chat
# Chat
# User
# User
# Channel
# User
# Channel
# Channel
# User
# Channel
# User
# Channel
# Chat
# User
# Chat
# User
# Chat
# Chat
# User
# Chat
# User
# Channel
# Chat
# Chat
# User
# User
# User
# Channel
# User
# Chat
# User
# Channel
# User
# User
# Channel
# User
# User
# User
# Channel
# User
# User
# User
# Chat
# Chat
# Chat
# User
# User
# User
# Chat
# User
# User
# Chat
# Chat
# Channel
# Channel
# Chat
# Chat
# Chat
# User
# User
# User
# Chat
# User
# User
# User
# Channel
# Channel
# Chat
# User
# Channel
# Channel
# Channel
# User
# User
# User
# User
# User
# Chat
# User
# User
# Chat
# Chat
# Chat
# Chat
# User
# User
# Chat
# User
# Channel
# Chat
# Chat
# User
# Chat
# Chat
# Channel
# Chat
# User
# User
# User
# Channel
# Chat
# Chat
# Chat
# User
# User
# User
# Channel
# Chat
# User
# Chat
# User
# User
# User
# Channel
# User
# Chat
# User
# Channel
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# User
# User
# Channel
# Chat
# Channel
# User
# Chat
# Chat
# Chat
# User
# Chat
# User
# Chat
# Chat
# Chat
# User
# User
# Chat
# Channel
# Channel
# User
# User
# Chat
# Chat
# User
# User
# Channel
# Chat
# Chat
# Channel
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# Channel
# Chat
# User
# Chat
# Channel
# Chat
# Chat
# User
# User
# User
# Channel
# User
# User
# User
# User
# Chat
# Chat
# Chat
# Channel
# Channel
# Chat
# Chat
# Chat
# Channel
# Chat
# Channel
# User
# User
# Chat
# Channel
# Chat
# Chat
# Channel
# Channel
# Chat
# Chat
# User
# User
# User
# User
# User
# User
# Chat
# User
# User
# User
# Chat
# User
# Chat
# Chat
# Chat
# Chat
# User
# User
# Chat
# Channel
# Chat
# Chat
# User
# User
# User
# Channel
# User
# Chat
# User
# User
# User
# User
# User
# User
# Chat
# Chat
# User
# Channel
# Chat
# Channel
# Channel
# Chat
# User
# Channel
# Chat
# Channel
# User
# Chat
# User
# User
# Chat
# Chat
# Chat
# User
# Chat
# Chat
# Channel
# User
# User
# User
# Chat
# User
# Chat
# Chat
# Chat
# Chat
# Channel
# Chat
# User
# User
# User
# Channel
# Channel
# Chat
# Chat
# Chat
# User
# Channel
# Chat
# Chat
# Chat
# User
# User
# User
# User
# Channel
# Chat
# User
# Chat
# Chat
# Chat
# User
# User
# Channel
# User
# User
# User
# User
# User
# User
# Chat
# Chat
# Channel
# User
# User
# User
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# User
# Chat
# User
# User
# User
# Channel
# Channel
# Channel
# Chat
# User
# User
# User
# Channel
# Chat
# User
# User
# User
# Channel
# Channel
# Channel
# Channel
# Chat
# Channel
# Chat
# User
# User
# User
# User
# Chat
# Channel
# Chat
# Chat
# User
# User
# Channel
# Channel
# Channel
# User
# User
# User
# Chat
# Channel
# Channel
# User
# Chat
# User
# Channel
# Channel
# User
# Chat
# Channel
# Chat
# User
# Channel
# Channel
# User
# Chat
# Channel
# User
# Chat
# User
# Channel
# Channel
# Channel
# Chat
# Channel
# User
# User
# User
# User
# User
# User
# Channel
# Channel
# Channel
# Channel
# User
# User
# Chat
# User
# User
# Channel
# Channel
# Chat
# Chat
# Chat
# Channel
# Channel
# User
# User
# User
# Chat
# User
# Channel
# Channel
# User
# User
# User
# User
# Channel
# Chat
# Chat
# User
# Chat
# Chat
# User
# Chat
# Channel
# Chat
# Channel
# User
# Chat
# Chat
# User
# User
# User
# User
# Channel
# Chat
# Chat
# Chat
# Chat
# Chat
# Channel
# Chat
# User
# User
# User
# Channel
# Chat
# Chat
# Chat
# Chat
# Chat
# User
# User
# Chat
# User
# User
# User
# User
# Channel
# Chat
# User
# User
# Chat
# Channel
# User
# Chat
# Chat
# Channel
# User
# User
# Channel
# User
# Chat
# Chat
# User
# Channel
# User
# Channel
# User
# User
# User
# User
# Channel
# Chat
# User
# Channel
# User
# Chat
# Chat
# User
# Chat
# Chat
# Channel
# User
# User
# Chat
# Chat
# Chat
# Chat
# Channel
# Chat
# User
# Channel
# User
# Chat
# Chat
# Channel
# Channel
# Chat
# User
# Channel
# Chat
# Channel
# Chat
# Chat
# Chat
# Channel
# Chat
# Channel
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# User
# Chat
# Channel
# Channel
# Chat
# Channel
# Chat
# Chat
# Chat
# Channel
# Chat
# Channel
# Channel
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Channel
# Channel
# Channel
# Chat
# Chat
# Chat
# Chat
# Channel
# Channel
# Channel
# Chat
# Channel
# Chat
# Channel
# User
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# User
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# User
# Chat
# User
# User
# Channel
# Chat
# User
# Channel
# User
# Chat
# User
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Channel
# User
# Channel
# Chat
# Chat
# Channel
# Chat
# Chat
# User
# User
# Chat
# Chat
# Chat
# Chat
# Chat
# Channel
# Chat
# Chat
# Channel
# User
# User
# User
# Chat
# Channel
# Chat
# Chat
# Channel
# Chat
# Channel
# Channel
# User
# User
# Channel
# Chat
# Chat
# Channel
# User
# Chat
# User
# User
# User
# Channel
# Chat
# User
# User
# User
# User
# Chat
# User
# Chat
# User
# Chat
# User
# Channel
# Chat
# User
# Channel
# Channel
# User
# User
# User
# Chat
# Chat
# User
# User
# User
# Chat
# User
# Chat
# Channel
# User
# User
# User
# User
# Chat
# User
# Chat
# User
# Chat
# Channel
# User
# Channel
# User
# User
# Chat
# Chat
# User
# User
# User
# User
# Channel
# Chat
# Chat
# Chat
# User
# User
# User
# Chat
# User
# Chat
# Chat
# Chat
# User
# Chat
# Chat
# Chat
# User
# User
# User
# Channel
# Channel
# Chat
# User
# User
# Chat
# Chat
# User
# User
# Chat
# Chat
# User
# Channel
# Chat
# Channel
# User
# Chat
# Chat
# Channel
# Chat
# Chat
# Chat
# Chat
# User
# User
# User
# User
# Channel
# Channel
# Channel
# User
# Chat
# Chat
# User
# User
# User
# Chat
# User
# User
# Chat
# User
# Chat
# Channel
# Channel
# Chat
# Chat
# Chat
# Chat
# User
# User
# Channel
# Chat
# User
# Chat
# User
# User
# User
# User
# Chat
# User
# Chat
# User
# User
# Chat
# User
# User
# Chat
# User
# Channel
# User
# User
# Channel
# Chat
# Chat
# Channel
# Channel
# Channel
# Channel
# Chat
# User
# Chat
# Chat
# Chat
# User
# User
# User
# Chat
# Chat
# Chat
# User
# User
# Chat
# Chat
# Channel
# Chat
# User
# User
# User
# Chat
# User
# User
# Chat
# Chat
# User
# Channel
# Channel
# User
# Channel
# Chat
# Channel
# Chat
# Channel
# Channel
# User
# User
# User
# User
# User
# Channel
# Chat
# Chat
# Chat
# Chat
# Chat
# Channel
# Chat
# User
# Chat
# User
# Chat
# Chat
# Chat
# User
# User
# Chat
# User
# User
# Chat
# Chat
# User
# User
# Chat
# Chat
# Chat
# User
# User
# User
# User
# Channel
# Chat
# User
# User
# User
# Chat
# Chat
# Chat
# User
# User
# User
# User
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# Chat
# User
# Chat
# Chat
# User
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# Chat
# Chat
# Chat
# Chat
# User
# Chat
# User
# User
# Chat
# Chat
# User
# Chat
# Chat
# User
# User
# Chat
# User
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# User
# User
# User
# User
# User
# Chat
# Chat
# Chat
# Chat
# User
# Chat
# Chat
# Chat
# User
# Chat
# Chat
# Chat
# User
# Chat
# Chat
# User
# User
# User
# Chat
# Chat
# User
# User
# User
# User
# Chat
# User
# Chat
# User
# Chat
# Channel
# Chat
# User
# User
# Chat
# Channel
# Channel
# Chat
# User
# Chat
# User
# Chat
# User
# User
# User
# User
# Chat
# Chat
# Channel
# User
# User
# Chat
# User
# Chat
# User
# User
# User
# Chat
# User
# User
# Chat
# User
# User
# User
# Chat
# Chat
# Chat
# User
# User
# User
# User
# Chat
# User
# User
# User
# Chat
# User
# Chat
# Chat
# User
# User
# Chat
# User
# User
# User
# User
# Chat
# User
# User
# User
# User
# Chat
# User
# Chat
# User
# Chat
# User
# User
# Chat
# User
# User
# Chat
# Chat
# Chat
# Chat
# Chat
# User
# Chat
# Chat
# User
# Chat
# User
# User
# User
# User
# User
# User
# Chat
# User
# User
# User
# Chat
# User
# Chat
# User
# Chat
# Chat
# User
# Chat
# User
# User
# User
# User
# Chat
# Chat
# User
# User
# User
# Chat
# Chat
# User
# Chat
# User
# Chat
# User
# Chat
# Chat
# Chat
# Chat
# User
# Chat
# User
# Chat
# Chat
# Chat
# Chat
# Chat
# Chat
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# User
# Chat
# Chat
# User
# Chat
# User
# Chat
# User
# Chat
# Chat
# User
# User
# User
# User
# User
# Chat
# Chat
# Chat
# User
# Chat
# User
# User
# User
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# User
# Chat
# Chat
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# Chat
# Chat
# Chat
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# Chat
# User
# Chat
# User
# Chat
# User
# Chat
# ChatForbidden
# Chat
# User
# Chat
# User
# Chat
# User
# User
# User
# User
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# Chat
# User
# Chat
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# Chat
# User
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# Chat
# User
# User
# User
# User
# User
# Chat
# Chat
# User
# User
# Chat
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# User
# Chat
# Chat
# User
# User
# User
# User
# User
# User
# User
# Chat
# User
# User
# Chat
# Chat
# User

# %%
str(type(channels[0].entity).__name__)
# Out:
# 'Channel'

# %%
dir(chat)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_client',
#  'archive',
#  'archived',
#  'date',
#  'delete',
#  'dialog',
#  'draft',
#  'entity',
#  'folder_id',
#  'id',
#  'input_entity',
#  'is_channel',
#  'is_group',
#  'is_user',
#  'message',
#  'name',
#  'pinned',
#  'send_message',
#  'stringify',
#  'title',
#  'to_dict',
#  'unread_count',
#  'unread_mentions_count']

# %%
chat.date
# chat.last_message_date
chat = groups[0]
chat.date

chat.entity.date
# Out:
# datetime.datetime(2024, 12, 5, 16, 35, 2, tzinfo=datetime.timezone.utc)

# %% [markdown]
# # Part 4

# %%
from pathlib import Path
import asyncio
from loguru import logger
from utils import setup_logger
from telethon_manager import TelethonClientManager, StorageMode
import os
from dotenv import load_dotenv
from datetime import datetime, timedelta
from typing import Dict, List, Any
import json
from get_chat_list import get_chats
from main import get_telethon_client
from download_messages_draft import get_messages_sample, save_messages, calculate_stats
import random

load_dotenv()
# setup_logger(logger, level="DEBUG" if debug else "INFO")

client = await get_telethon_client()
# if not client:
#     logger.error("Failed to get client")
#     return

chats = await get_chats()
logger.info(f"Found {len(chats)} chats")

# let's select a random sub-sample of chats
random.shuffle(chats)
chats = chats[:20]

messages = await get_messages_sample(client,
                                     chats)  # Start with just 5 chats for testing
logger.info(f"Downloaded messages from {len(messages)} chats")

save_messages(messages)
# Out:
# 2024-12-30 13:00:16.249 | DEBUG    | telethon_manager:__init__:24 - TelethonManager initialized with storage_mode: StorageMode.TO_DISK
# 2024-12-30 13:00:16.249 | DEBUG    | telethon_manager:__init__:25 - TelethonManager initialized with sessions dir: sessions
# 2024-12-30 13:00:16.249 | DEBUG    | telethon_manager:get_telethon_client:28 - Getting telethon client for user 291560340 with storage mode StorageMode.TO_DISK
# 2024-12-30 13:00:16.249 | DEBUG    | telethon_manager:_get_telethon_client_from_disk:36 - Attempting to get telethon client from disk for user 291560340
# 2024-12-30 13:00:16.250 | DEBUG    | telethon_manager:_check_if_conn_is_present_on_disk:115 - Checking if session file exists for user 291560340: True
# 2024-12-30 13:00:16.250 | DEBUG    | telethon_manager:_get_telethon_client_from_disk:38 - Found existing connection on disk for user 291560340
# 2024-12-30 13:00:16.250 | DEBUG    | telethon_manager:_load_conn_from_disk:122 - Loading session for user 291560340 from sessions/user_291560340.session
# 2024-12-30 13:00:16.252 | DEBUG    | telethon_manager:_load_conn_from_disk:130 - Attempting to connect existing client for user 291560340
# 2024-12-30 13:00:16.632 | DEBUG    | telethon_manager:_load_conn_from_disk:134 - Session authorization check for user 291560340: True
# 2024-12-30 13:00:16.633 | DEBUG    | telethon_manager:_load_conn_from_disk:138 - Successfully loaded and authorized client for user 291560340
# 2024-12-30 13:00:16.636 | DEBUG    | get_chat_list:get_chats:55 - Getting chats asynchronously
# 2024-12-30 13:00:16.637 | DEBUG    | get_chat_list:_has_fresh_chats_on_disk:141 - Checking for fresh chats on disk
# 2024-12-30 13:00:16.653 | DEBUG    | get_chat_list:_has_fresh_chats_on_disk:151 - Chats on disk are fresh
# 2024-12-30 13:00:16.654 | DEBUG    | get_chat_list:get_chats:57 - Found fresh chats on disk
# 2024-12-30 13:00:16.654 | DEBUG    | get_chat_list:_get_chats_from_disk:96 - Loading chats from disk
# 2024-12-30 13:00:16.698 | INFO     | get_chat_list:_load_chats_from_json:92 - Loaded 1778 entities from data/chats.json
# 2024-12-30 13:00:16.699 | DEBUG    | get_chat_list:_get_chats_from_disk:101 - Loaded 1778 chats from disk
# 2024-12-30 13:00:16.699 | INFO     | __main__:<module>:25 - Found 1778 chats
# 2024-12-30 13:00:16.701 | DEBUG    | download_messages_draft:get_messages_sample:17 - Getting 100 messages from each chat
# 2024-12-30 13:00:19.508 | INFO     | __main__:<module>:32 - Downloaded messages from 20 chats
# 2024-12-30 13:00:19.509 | DEBUG    | download_messages_draft:save_messages:45 - Saving messages placeholder - implement proper storage later
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 36
#      32 logger.info(f"Downloaded messages from {len(messages)} chats")
#      34 save_messages(messages)
# ---> 36 stats = calculate_stats(messages)
#      37 logger.info("Message statistics:")
#      38 for key, value in stats.items():
#
# File ~/work/projects/calmmage/seasonal/season_1_dec_2024/draft/download-telegram-messages/draft_3/download_messages_draft.py:55, in calculate_stats(messages_by_chat)
#      52 def calculate_stats(messages_by_chat):
#      53     stats = {
#      54         'total_chats': len(messages_by_chat),
# ---> 55         'total_messages': sum(len(chat['messages']) for chat in messages_by_chat.values()),
#      56         'chats_with_media': sum(
#      57             1 for chat in messages_by_chat.values()
#      58             if any(msg['has_media'] for msg in chat['messages'])
#      59         )
#      60     }
#      62     # TODO: Add more advanced stats in jupyter notebook:
#      63     # - Message length distribution
#      64     # - Time patterns (hour of day, day of week)
#      65     # - Media type distribution
#      66     # - Most active chats
#      67     # - Most active users
#      69     return stats
#
# File ~/work/projects/calmmage/seasonal/season_1_dec_2024/draft/download-telegram-messages/draft_3/download_messages_draft.py:55, in <genexpr>(.0)
#      52 def calculate_stats(messages_by_chat):
#      53     stats = {
#      54         'total_chats': len(messages_by_chat),
# ---> 55         'total_messages': sum(len(chat['messages']) for chat in messages_by_chat.values()),
#      56         'chats_with_media': sum(
#      57             1 for chat in messages_by_chat.values()
#      58             if any(msg['has_media'] for msg in chat['messages'])
#      59         )
#      60     }
#      62     # TODO: Add more advanced stats in jupyter notebook:
#      63     # - Message length distribution
#      64     # - Time patterns (hour of day, day of week)
#      65     # - Media type distribution
#      66     # - Most active chats
#      67     # - Most active users
#      69     return stats
#
# TypeError: list indices must be integers or slices, not str

# %%
stats = calculate_stats(messages)
logger.info("Message statistics:")
for key, value in stats.items():
    logger.info(f"{key}: {value}")

# %%
cd = {c['entity'].id: c for c in chats}

# %%
from get_chat_list import categorize_entity


def get_chat_info(chat_id):
    res = {}
    try:
        res['username'] = cd[chat_id]['entity'].username
    except:
        res['username'] = None
    try:
        res['title'] = cd[chat_id]['entity'].title
    except:
        res['title'] = None
    res['type'] = categorize_entity(cd[chat_id]['entity'])
    return res


get_chat_info(4285323792)
# Out:
# {'username': None,
#  'title': 'Проект 146: Лекторий выпускников',
#  'type': 'group'}

# %%
message = messages[768142633][0]

for attr in dir(message):
    if not attr.startswith('_'):  # Skip private attributes
        print(f"{attr}: {getattr(message, attr)}")
# Out:
# CONSTRUCTOR_ID: 2486456898
# SUBCLASS_OF_ID: 2030045667
# action: None
# action_entities: None
# audio: None
# button_count: 0
# buttons: None
# chat: User(id=768142633, is_self=False, contact=False, mutual_contact=False, deleted=False, bot=False, bot_chat_history=False, bot_nochats=False, verified=False, restricted=False, min=False, bot_inline_geo=False, support=False, scam=False, apply_min_photo=True, fake=False, bot_attach_menu=False, premium=True, attach_menu_enabled=False, bot_can_edit=False, close_friend=False, stories_hidden=False, stories_unavailable=True, contact_require_premium=False, bot_business=False, bot_has_main_app=False, access_hash=-2579813437544972286, first_name='Степан', last_name='Хачатрян', username='etuighd', phone=None, photo=UserProfilePhoto(photo_id=3299147487854569396, dc_id=2, has_video=False, personal=False, stripped_thumb=b'\x01\x08\x08\x8ef\xce\xe0\x089^\xdd\xb9\x14QE!\x9f'), status=UserStatusRecently(by_me=False), bot_info_version=None, restriction_reason=[], bot_inline_placeholder=None, lang_code=None, emoji_status=EmojiStatus(document_id=5413694143601842851), usernames=[], stories_max_id=None, color=None, profile_color=None, bot_active_users=None)
# chat_id: 768142633
# click: <bound method Message.click of <telethon.tl.patched.Message object at 0x119a77310>>
# client: <telethon.client.telegramclient.TelegramClient object at 0x10dcb6110>
# contact: None
# date: 2024-01-23 17:11:11+00:00
# delete: <bound method Message.delete of <telethon.tl.patched.Message object at 0x119a77310>>
# dice: None
# document: None
# download_media: <bound method Message.download_media of <telethon.tl.patched.Message object at 0x119a77310>>
# edit: <bound method Message.edit of <telethon.tl.patched.Message object at 0x119a77310>>
# edit_date: None
# edit_hide: False
# effect: None
# entities: None
# factcheck: None
# file: None
# forward: None
# forward_to: <bound method Message.forward_to of <telethon.tl.patched.Message object at 0x119a77310>>
# forwards: None
# from_boosts_applied: None
# from_id: None
# from_reader: <bound method Message.from_reader of <class 'telethon.tl.patched.Message'>>
# from_scheduled: False
# fwd_from: None
# game: None
# geo: None
# get_buttons: <bound method Message.get_buttons of <telethon.tl.patched.Message object at 0x119a77310>>
# get_chat: <bound method ChatGetter.get_chat of <telethon.tl.patched.Message object at 0x119a77310>>
# get_entities_text: <bound method Message.get_entities_text of <telethon.tl.patched.Message object at 0x119a77310>>
# get_input_chat: <bound method ChatGetter.get_input_chat of <telethon.tl.patched.Message object at 0x119a77310>>
# get_input_sender: <bound method SenderGetter.get_input_sender of <telethon.tl.patched.Message object at 0x119a77310>>
# get_reply_message: <bound method Message.get_reply_message of <telethon.tl.patched.Message object at 0x119a77310>>
# get_sender: <bound method SenderGetter.get_sender of <telethon.tl.patched.Message object at 0x119a77310>>
# gif: None
# grouped_id: None
# id: 239203
# input_chat: InputPeerUser(user_id=768142633, access_hash=-2579813437544972286)
# input_sender: InputPeerUser(user_id=768142633, access_hash=-2579813437544972286)
# invert_media: False
# invoice: None
# is_channel: False
# is_group: False
# is_private: True
# is_reply: False
# legacy: False
# mark_read: <bound method Message.mark_read of <telethon.tl.patched.Message object at 0x119a77310>>
# media: None
# media_unread: False
# mentioned: False
# message: Петя,привет.
# Я сосед Левы,Степан.
# Скажи пожалуйста,можешь ли ты,помочь мне с созданием резюме по проджекту.
# noforwards: False
# offline: False
# out: False
# peer_id: PeerUser(user_id=768142633)
# photo: None
# pin: <bound method Message.pin of <telethon.tl.patched.Message object at 0x119a77310>>
# pinned: False
# poll: None
# post: False
# post_author: None
# pretty_format: <function TLObject.pretty_format at 0x10b3411c0>
# quick_reply_shortcut_id: None
# raw_text: Петя,привет.
# Я сосед Левы,Степан.
# Скажи пожалуйста,можешь ли ты,помочь мне с созданием резюме по проджекту.
# reactions: None
# replies: None
# reply: <bound method Message.reply of <telethon.tl.patched.Message object at 0x119a77310>>
# reply_markup: None
# reply_to: None
# reply_to_chat: None
# reply_to_msg_id: None
# reply_to_sender: None
# respond: <bound method Message.respond of <telethon.tl.patched.Message object at 0x119a77310>>
# restriction_reason: None
# saved_peer_id: None
# sender: User(id=768142633, is_self=False, contact=False, mutual_contact=False, deleted=False, bot=False, bot_chat_history=False, bot_nochats=False, verified=False, restricted=False, min=False, bot_inline_geo=False, support=False, scam=False, apply_min_photo=True, fake=False, bot_attach_menu=False, premium=True, attach_menu_enabled=False, bot_can_edit=False, close_friend=False, stories_hidden=False, stories_unavailable=True, contact_require_premium=False, bot_business=False, bot_has_main_app=False, access_hash=-2579813437544972286, first_name='Степан', last_name='Хачатрян', username='etuighd', phone=None, photo=UserProfilePhoto(photo_id=3299147487854569396, dc_id=2, has_video=False, personal=False, stripped_thumb=b'\x01\x08\x08\x8ef\xce\xe0\x089^\xdd\xb9\x14QE!\x9f'), status=UserStatusRecently(by_me=False), bot_info_version=None, restriction_reason=[], bot_inline_placeholder=None, lang_code=None, emoji_status=EmojiStatus(document_id=5413694143601842851), usernames=[], stories_max_id=None, color=None, profile_color=None, bot_active_users=None)
# sender_id: 768142633
# serialize_bytes: <function TLObject.serialize_bytes at 0x10b341260>
# serialize_datetime: <function TLObject.serialize_datetime at 0x10b341300>
# silent: False
# sticker: None
# stringify: <bound method TLObject.stringify of <telethon.tl.patched.Message object at 0x119a77310>>
# text: Петя,привет.
# Я сосед Левы,Степан.
# Скажи пожалуйста,можешь ли ты,помочь мне с созданием резюме по проджекту.
# to_dict: <bound method Message.to_dict of <telethon.tl.patched.Message object at 0x119a77310>>
# to_id: PeerUser(user_id=291560340)
# to_json: <bound method TLObject.to_json of <telethon.tl.patched.Message object at 0x119a77310>>
# ttl_period: None
# unpin: <bound method Message.unpin of <telethon.tl.patched.Message object at 0x119a77310>>
# venue: None
# via_bot: None
# via_bot_id: None
# via_business_bot_id: None
# via_input_bot: None
# video: None
# video_note: None
# video_processing_pending: False
# views: None
# voice: None
# web_preview: None

# %%
print(message.stringify())
# Out:
# Message(
# 	id=239203,
# 	peer_id=PeerUser(
# 		user_id=768142633
# 	),
# 	date=datetime.datetime(2024, 1, 23, 17, 11, 11, tzinfo=datetime.timezone.utc),
# 	message='Петя,привет. \nЯ сосед Левы,Степан. \nСкажи пожалуйста,можешь ли ты,помочь мне с созданием резюме по проджекту.',
# 	out=False,
# 	mentioned=False,
# 	media_unread=False,
# 	silent=False,
# 	post=False,
# 	from_scheduled=False,
# 	legacy=False,
# 	edit_hide=False,
# 	pinned=False,
# 	noforwards=False,
# 	invert_media=False,
# 	offline=False,
# 	video_processing_pending=False,
# 	from_id=None,
# 	from_boosts_applied=None,
# 	saved_peer_id=None,
# 	fwd_from=None,
# 	via_bot_id=None,
# 	via_business_bot_id=None,
# 	reply_to=None,
# 	media=None,
# 	reply_markup=None,
# 	entities=[
# 	],
# 	views=None,
# 	forwards=None,
# 	replies=None,
# 	edit_date=None,
# 	post_author=None,
# 	grouped_id=None,
# 	reactions=None,
# 	restriction_reason=[
# 	],
# 	ttl_period=None,
# 	quick_reply_shortcut_id=None,
# 	effect=None,
# 	factcheck=None
# )

# %%
print(message.to_json(indent=2, ensure_ascii=False))
# Out:
# {
#   "_": "Message",
#   "id": 239203,
#   "peer_id": {
#     "_": "PeerUser",
#     "user_id": 768142633
#   },
#   "date": "2024-01-23T17:11:11+00:00",
#   "message": "Петя,привет. \nЯ сосед Левы,Степан. \nСкажи пожалуйста,можешь ли ты,помочь мне с созданием резюме по проджекту.",
#   "out": false,
#   "mentioned": false,
#   "media_unread": false,
#   "silent": false,
#   "post": false,
#   "from_scheduled": false,
#   "legacy": false,
#   "edit_hide": false,
#   "pinned": false,
#   "noforwards": false,
#   "invert_media": false,
#   "offline": false,
#   "video_processing_pending": false,
#   "from_id": null,
#   "from_boosts_applied": null,
#   "saved_peer_id": null,
#   "fwd_from": null,
#   "via_bot_id": null,
#   "via_business_bot_id": null,
#   "reply_to": null,
#   "media": null,
#   "reply_markup": null,
#   "entities": [],
#   "views": null,
#   "forwards": null,
#   "replies": null,
#   "edit_date": null,
#   "post_author": null,
#   "grouped_id": null,
#   "reactions": null,
#   "restriction_reason": [],
#   "ttl_period": null,
#   "quick_reply_shortcut_id": null,
#   "effect": null,
#   "factcheck": null
# }

# %%
c1 = cd[4285323792]['entity']
print(c1.to_json(indent=2, ensure_ascii=False))
# Out:
# {
#   "_": "Chat",
#   "id": 4285323792,
#   "title": "Проект 146: Лекторий выпускников",
#   "photo": {
#     "_": "ChatPhotoEmpty"
#   },
#   "participants_count": 0,
#   "date": "2024-05-23T14:58:09+00:00",
#   "version": 4,
#   "creator": true,
#   "left": false,
#   "deactivated": true,
#   "call_active": false,
#   "call_not_empty": false,
#   "noforwards": false,
#   "migrated_to": {
#     "_": "InputChannel",
#     "channel_id": 2225560544,
#     "access_hash": 4322926735019715355
#   },
#   "admin_rights": null,
#   "default_banned_rights": null
# }

# %%
from collections import defaultdict


def calculate_stats(messages):
    # a) total messages
    # b) peak messages / day
    # c) peak messages / month
    # d) total messages last year
    # e) chats with media

    stats = {}

    for chat_id, m in messages.items():
        s = {}
        s['total_messages'] = len(m)
        s['media_count'] = sum(1 for message in m if message.media)

        # calculate peak messages / day
        messages_counts_by_day = defaultdict(int)
        for message in m:
            messages_counts_by_day[message.date.date()] += 1
        s['peak_messages_per_day'] = max(messages_counts_by_day.values())

        # calculate peak messages / month
        messages_counts_by_month = defaultdict(int)
        for message in m:
            messages_counts_by_month[message.date.month] += 1
        s['peak_messages_per_month'] = max(messages_counts_by_month.values())

        # calculate total messages last year
        s['total_messages_last_year'] = sum(
            1 for message in m if message.date.year == datetime.now().year - 1)

        stats[chat_id] = s
    return stats

# %%
stats = calculate_stats(messages)

# %%
# let's plot stats
from matplotlib import pyplot as plt
import seaborn as sns

# sns.set_style("whitegrid")
plt.style.use('dark_background')
# sns.set_style("darkgrid")
# sns.set_palette("husl")
# sns.set_palette("pastel")
sns.set_palette("deep")  # Using deep palette which shows better on dark background


def plot_stats(stats):
    for key in [
        'total_messages',
        'peak_messages_per_day',
        'peak_messages_per_month',
        'total_messages_last_year',
        'media_count'
    ]:
        # Create histogram
        plt.figure(figsize=(10, 6))
        plt.hist([s[key] for s in stats.values()], bins=20)
        plt.title(f"Distribution of {key}")
        plt.xlabel(key)
        plt.ylabel("Count")
        plt.show()


plot_stats(stats)

# %%
# let's save and load messages

def save_messages(messages, path="data/messages.json"):
    data = {
        k: [v.to_json(indent=2, ensure_ascii=False) for v in v]
        for k, v in messages.items()
    }
    with open(path, "w") as f:
        json.dump(data, f, indent=2)


from telethon.tl.types import Message, MessageService

type_map = {
    'Message': lambda x: Message(**x),
    'MessageService': lambda x: MessageService(**x),
}


def load_messages(path="data/messages.json"):
    messages = {}
    error_count = 0
    with open(path, "r") as f:
        data = json.load(f)
        for k, v in data.items():
            messages[k] = []
            for vv in v:
                d = json.loads(vv)
                data_type = type_map[d.pop("_")]
                try:
                    messages[k].append(data_type(d))
                except Exception as e:
                    messages[k].append(d)
                    error_count += 1

    logger.info(f"Error count: {error_count}")
    return messages


save_messages(messages)
mm = load_messages()
# Out:
# 2024-12-30 14:00:00.888 | INFO     | __main__:load_messages:32 - Error count: 424

# %%
mm
# Out:
# {'4285323792': [{'id': 253073,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 4285323792},
#    'date': '2024-05-23T14:58:09+00:00',
#    'action': {'_': 'MessageActionChatCreate',
#     'title': 'Проект 146: Лекторий выпускников',
#     'users': [291560340]},
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'legacy': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'reply_to': None,
#    'ttl_period': None},
#   {'id': 253078,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 4285323792},
#    'date': '2024-05-23T15:36:12+00:00',
#    'action': {'_': 'MessageActionChatJoinedByLink', 'inviter_id': 1087968824},
#    'out': False,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'legacy': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 139463400},
#    'reply_to': None,
#    'ttl_period': None},
#   {'id': 253079,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 4285323792},
#    'date': '2024-05-23T15:36:32+00:00',
#    'action': {'_': 'MessageActionChatJoinedByLink', 'inviter_id': 1087968824},
#    'out': False,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'legacy': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 258073593},
#    'reply_to': None,
#    'ttl_period': None},
#   {'id': 253080,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 4285323792},
#    'date': '2024-05-23T15:37:44+00:00',
#    'message': 'Страничка с конкретной идеей (WIP)\nhttps://petrlavrov.notion.site/6e58a904985b40718eaf4a40953f2900?pvs=4\n\nБольшая страничка со встречи (часть идей там, пока не добавил внутрь страницы проекта\nhttps://petrlavrov.notion.site/146-intro-c9bee8bc59a04eafbd80e18cba2c6727?pvs=4\n\nКто готов работать - попросите у меня доступ - выдам (нужна почта в Notion)\nИли предлагайте другой формат',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaWebPage',
#     'webpage': {'_': 'WebPage',
#      'id': 7191397832484270485,
#      'url': 'https://petrlavrov.notion.site/6e58a904985b40718eaf4a40953f2900?pvs=4',
#      'display_url': 'petrlavrov.notion.site/6e58a904985b40718eaf4a40953f2900?pvs=4',
#      'hash': 0,
#      'has_large_media': True,
#      'type': 'photo',
#      'site_name': 'Petr Lavrov on Notion',
#      'title': 'Лекции от выпускников | Notion',
#      'description': 'Место для обсуждения - отдельный чат в телеграме - “Проект 146: Лекторий выпускников” https://t.me/+f4tlZys_k4tlMmEy',
#      'photo': {'_': 'Photo',
#       'id': 5842336729216955242,
#       'access_hash': 6168979110962940177,
#       'file_reference': 'AGdybzdvcy0exJsjxoNUN/A9UPij',
#       'date': '2024-01-12T21:35:10+00:00',
#       'sizes': [{'_': 'PhotoStrippedSize',
#         'type': 'i',
#         'bytes': 'ARUo16KKqy20jzs6sNrY4oAtUVCYZSxInYAnpj3p0aOrZaUsPTGKAJKKKKACiiigAooooAKKKKAP'},
#        {'_': 'PhotoSize', 'type': 'm', 'w': 320, 'h': 168, 'size': 3434},
#        {'_': 'PhotoSize', 'type': 'x', 'w': 800, 'h': 420, 'size': 11783},
#        {'_': 'PhotoSizeProgressive',
#         'type': 'y',
#         'w': 1200,
#         'h': 630,
#         'sizes': [3469, 5444, 9149, 11530, 17201]}],
#       'dc_id': 4,
#       'has_stickers': False,
#       'video_sizes': []},
#      'embed_url': None,
#      'embed_type': None,
#      'embed_width': None,
#      'embed_height': None,
#      'duration': None,
#      'author': 'Petr Lavrov',
#      'document': None,
#      'cached_page': None,
#      'attributes': []},
#     'force_large_media': False,
#     'force_small_media': False,
#     'manual': True,
#     'safe': True},
#    'reply_markup': None,
#    'entities': [{'_': 'MessageEntityUrl', 'offset': 35, 'length': 69},
#     {'_': 'MessageEntityUrl', 'offset': 192, 'length': 79}],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 253081,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 4285323792},
#    'date': '2024-05-23T15:40:54+00:00',
#    'message': 'Идея что здесь говорилось:\n- Онлайн \n- Оффлайн\n- 7 лекций на неделю втречи выпускников\n\nНе путать с проектом "Random Coffee 146" и его прототипом на неделе выпуского (а-ля менторский Speed-Dating)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaWebPage',
#     'webpage': {'_': 'WebPage',
#      'id': 3463749425214364706,
#      'url': 'https://t.me/+EOkDbqLEIc82ZTMy',
#      'display_url': 't.me/+EOkDbqLEIc82ZTMy',
#      'hash': 0,
#      'has_large_media': False,
#      'type': 'telegram_chat',
#      'site_name': 'Telegram',
#      'title': 'Проект 146: Random Coffee, Speed dating, Выпускник-выпускник или выпускник-школьник',
#      'description': 'Petr Lavrov invites you to join this group on Telegram.',
#      'photo': None,
#      'embed_url': None,
#      'embed_type': None,
#      'embed_width': None,
#      'embed_height': None,
#      'duration': None,
#      'author': None,
#      'document': None,
#      'cached_page': None,
#      'attributes': []},
#     'force_large_media': False,
#     'force_small_media': False,
#     'manual': True,
#     'safe': True},
#    'reply_markup': None,
#    'entities': [{'_': 'MessageEntityTextUrl',
#      'offset': 110,
#      'length': 17,
#      'url': 'https://t.me/+EOkDbqLEIc82ZTMy'}],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': '2024-05-23T15:43:21+00:00',
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 253083,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 4285323792},
#    'date': '2024-05-23T15:43:13+00:00',
#    'action': {'_': 'MessageActionChatJoinedByLink', 'inviter_id': 1087968824},
#    'out': False,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'legacy': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 219723478},
#    'reply_to': None,
#    'ttl_period': None},
#   {'id': 253085,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 4285323792},
#    'date': '2024-05-23T15:44:05+00:00',
#    'action': {'_': 'MessageActionChatMigrateTo', 'channel_id': 2225560544},
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'legacy': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'reply_to': None,
#    'ttl_period': None}],
#  '768142633': [<telethon.tl.patched.Message at 0x11ca93ed0>,
#   {'id': 239205,
#    'peer_id': {'_': 'PeerUser', 'user_id': 768142633},
#    'date': '2024-01-23T17:26:52+00:00',
#    'message': 'Привет!\nА что ты уже сделал?',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11c92dad0>,
#   <telethon.tl.patched.Message at 0x11ca81890>,
#   <telethon.tl.patched.Message at 0x11fadfa50>,
#   {'id': 239209,
#    'peer_id': {'_': 'PeerUser', 'user_id': 768142633},
#    'date': '2024-01-23T17:28:17+00:00',
#    'message': 'В направлении написания резюме)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 239210,
#    'peer_id': {'_': 'PeerUser', 'user_id': 768142633},
#    'date': '2024-01-23T17:28:57+00:00',
#    'message': '',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaPhoto',
#     'spoiler': False,
#     'photo': {'_': 'Photo',
#      'id': 5296311498152466531,
#      'access_hash': 6501285945032970398,
#      'file_reference': 'AwADpmpncm83ZZ0e8t6Pxwh8z3pTpy1FbA==',
#      'date': '2024-01-23T17:28:56+00:00',
#      'sizes': [{'_': 'PhotoStrippedSize',
#        'type': 'i',
#        'bytes': 'AQUozcD0owPSiigYYHpRgelFFACYHpRRRQB/'},
#       {'_': 'PhotoSize', 'type': 'm', 'w': 320, 'h': 43, 'size': 2392},
#       {'_': 'PhotoSize', 'type': 'x', 'w': 800, 'h': 107, 'size': 9445},
#       {'_': 'PhotoSizeProgressive',
#        'type': 'y',
#        'w': 1222,
#        'h': 164,
#        'sizes': [1420, 3253, 5334, 7126, 11906]}],
#      'dc_id': 2,
#      'has_stickers': False,
#      'video_sizes': []},
#     'ttl_seconds': None},
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11d56dbd0>,
#   <telethon.tl.patched.Message at 0x11cf93fd0>],
#  '1144267645': [<telethon.tl.patched.Message at 0x11cf917d0>,
#   <telethon.tl.patched.Message at 0x11cced1d0>,
#   {'id': 109616,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-07-02T11:04:36+00:00',
#    'message': 'Спасибо)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11d560450>,
#   <telethon.tl.patched.Message at 0x11c9c6dd0>,
#   <telethon.tl.patched.Message at 0x167a18290>,
#   {'id': 110367,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-07-07T08:41:36+00:00',
#    'message': 'Сформулируйте претензию🙄',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x167a19590>,
#   <telethon.tl.patched.Message at 0x11cf52a50>,
#   {'id': 110375,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-07-07T08:46:32+00:00',
#    'message': 'Спасибо :)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 110376,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-07-07T08:47:40+00:00',
#    'message': 'Я бы ещё сказал что "лекция" подразумевает что у тебя уже есть готовая лекция. Что навряд ли)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11cf52a90>,
#   <telethon.tl.patched.Message at 0x11c8f94d0>,
#   {'id': 110379,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-07-07T08:48:20+00:00',
#    'message': 'Про не в Москве и не состоишь - это мой косяк 🙄 Я тебя вписал',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11c8faed0>,
#   <telethon.tl.patched.Message at 0x11ccf98d0>,
#   <telethon.tl.patched.Message at 0x11cdf4310>,
#   <telethon.tl.patched.Message at 0x11cbfe0d0>,
#   {'id': 110739,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-07-09T12:39:44+00:00',
#    'message': 'Sooo..',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 110748,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-07-09T12:46:01+00:00',
#    'message': 'Дела как обычно - очень хорошо, но очень много.. И, в общем, больше уже не мяу)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 110749,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-07-09T12:46:39+00:00',
#    'message': 'Сочувствую :( Они не стали прививки ставить? Или в Перми хрен поставишь?',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': {'_': 'MessageReplyHeader',
#     'reply_to_scheduled': False,
#     'forum_topic': False,
#     'quote': False,
#     'reply_to_msg_id': 110390,
#     'reply_to_peer_id': None,
#     'reply_from': None,
#     'reply_media': None,
#     'reply_to_top_id': None,
#     'quote_text': None,
#     'quote_entities': [],
#     'quote_offset': None},
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 113715,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-05T07:39:50+00:00',
#    'message': 'Привет',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 113716,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-05T07:40:51+00:00',
#    'message': 'Тебе удобнее будет если я одежду в Пермь передам вместе с ключами, или лучше здесь пусть будет?',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 113717,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-05T07:40:52+00:00',
#    'message': '',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaPhoto',
#     'spoiler': False,
#     'photo': {'_': 'Photo',
#      'id': 5213108545585788339,
#      'access_hash': -7986348770201254805,
#      'file_reference': 'AwABvDVncm84Jwcbt+GNnaXQFExlnXWgeA==',
#      'date': '2021-08-05T07:40:52+00:00',
#      'sizes': [{'_': 'PhotoStrippedSize',
#        'type': 'i',
#        'bytes': 'ASgejZ8w7TIucYwBnNRBGIyBmppoI0kjjjyC348VM4EYAXpipvYfWxSB2uCOxrbhkEkYYVjugaQ9s1bsJdisjnGKSkmU4OO5VMxkm3jgLwKUzO55OfwqBeAPxpVJyfY02hJ63LJAqASYwV78Unmup559KRgBAvTOetZxjyvU2lJTVkNDACk385FFFamAhbNJRRQB'},
#       {'_': 'PhotoSize', 'type': 'm', 'w': 240, 'h': 320, 'size': 23452},
#       {'_': 'PhotoSize', 'type': 'x', 'w': 600, 'h': 800, 'size': 116382},
#       {'_': 'PhotoSizeProgressive',
#        'type': 'y',
#        'w': 960,
#        'h': 1280,
#        'sizes': [14408, 36444, 47489, 85943, 164014]}],
#      'dc_id': 2,
#      'has_stickers': False,
#      'video_sizes': []},
#     'ttl_seconds': None},
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11d112050>,
#   <telethon.tl.patched.Message at 0x11c91d690>,
#   <telethon.tl.patched.Message at 0x11cb86490>,
#   {'id': 113726,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-05T07:57:44+00:00',
#    'message': 'Да, хорошо, отправил с Левой :)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 114655,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:14:51+00:00',
#    'message': 'А ты мне можешь подсказать где в Перми бородавки можно вывести?',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 114656,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:15:08+00:00',
#    'message': 'Пожалуйста :)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11cb85ad0>,
#   {'id': 114662,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:28:10+00:00',
#    'message': 'Привет 🙄',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11cf66d10>,
#   <telethon.tl.patched.Message at 0x11cf64390>,
#   {'id': 114665,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:31:43+00:00',
#    'message': 'О, супер, мы рандомно записались в нее же :)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11cf67810>,
#   <telethon.tl.patched.Message at 0x11cb16c90>,
#   <telethon.tl.patched.Message at 0x11cb15710>,
#   {'id': 114669,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:32:59+00:00',
#    'message': 'Неа',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x167de26d0>,
#   <telethon.tl.patched.Message at 0x11cb16690>,
#   {'id': 114672,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:33:38+00:00',
#    'message': 'Спросил у фейсбука',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 114673,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:33:45+00:00',
#    'message': 'Чё там по их офферу)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 114674,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:33:56+00:00',
#    'message': 'Ну а в целом',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 114675,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:34:09+00:00',
#    'message': 'Стрёмно конечно что так затягивается',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 114676,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:34:20+00:00',
#    'message': 'И страшно что могут вообще не дать визу',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x11cb17190>,
#   {'id': 114678,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:35:00+00:00',
#    'message': 'Но в целом я доволен тем как все сложилось)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x167db6050>,
#   <telethon.tl.patched.Message at 0x167db44d0>,
#   <telethon.tl.patched.Message at 0x167db56d0>,
#   <telethon.tl.patched.Message at 0x167db6c50>,
#   {'id': 114683,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:36:31+00:00',
#    'message': '18)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x167db6dd0>,
#   {'id': 114685,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:38:30+00:00',
#    'message': 'Спасибо)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 114686,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:42:11+00:00',
#    'message': 'Хз через кого. У меня все contact persons твердят как один что "we see delays across board, do everything we can"',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': {'_': 'MessageReplyHeader',
#     'reply_to_scheduled': False,
#     'forum_topic': False,
#     'quote': False,
#     'reply_to_msg_id': 114681,
#     'reply_to_peer_id': None,
#     'reply_from': None,
#     'reply_media': None,
#     'reply_to_top_id': None,
#     'quote_text': None,
#     'quote_entities': [],
#     'quote_offset': None},
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x167db4d90>,
#   <telethon.tl.patched.Message at 0x167ef5410>,
#   {'id': 114689,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:42:58+00:00',
#    'message': 'Мне не горит)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 114690,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:43:05+00:00',
#    'message': 'Я ещё на работу вышел',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x167ef4490>,
#   {'id': 114693,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-12T12:59:46+00:00',
#    'message': 'Да, делать ботов которые играют в покер в Китае)',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   <telethon.tl.patched.Message at 0x167ef4e10>,
#   <telethon.tl.patched.Message at 0x167ee3f10>,
#   {'id': 115304,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-16T21:36:55+00:00',
#    'message': 'https://photos.app.goo.gl/ojjJkDknrz6xBd8F8',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaWebPage',
#     'webpage': {'_': 'WebPage',
#      'id': 3836411266176538734,
#      'url': 'https://photos.app.goo.gl/ojjJkDknrz6xBd8F8',
#      'display_url': 'photos.google.com/share/AF1QipOr7GZNUnxe9oLVGKvheIzuJ-V1QL1kkhJ_dXlW8e87erxNp7-svXqM2WqYAZcxow?key=ZUFxbDJUTkM1NUwwb2hzRzVmcDNVT2JuQ0pNTFFR&hl=en',
#      'hash': 0,
#      'has_large_media': True,
#      'type': 'photo',
#      'site_name': 'Google Photos',
#      'title': '11в 2010 146',
#      'description': '1057 new items added to shared album',
#      'photo': {'_': 'Photo',
#       'id': 5831051397704037633,
#       'access_hash': -5338219744040466515,
#       'file_reference': 'AGdybzhnTTePfWk28McgMJVazpvT',
#       'date': '2024-07-21T10:09:08+00:00',
#       'sizes': [{'_': 'PhotoStrippedSize',
#         'type': 'i',
#         'bytes': 'ARUoX7LEmxwx+UY6VEqDyjlMhegI60hkZwCpzu6ConkEZYc89utJK243toSFUjh4wcpnHpUcYEsq7xkEdcHAxUkboUJdCWIwvuKYY5HwYlJBGeOtOwFq5th5G4HpgD6UVBbSSS5jLfu16jHvRS2DcZBxgk5xkVIsqxzowjBYgsGJ5HOKKKOo/sj2Pntx8gxnA/lTZpDGm5QOf0/zmiinElkcshidyvG7k++P/wBdFFFJ7jM='},
#        {'_': 'PhotoSize', 'type': 'm', 'w': 320, 'h': 168, 'size': 24828},
#        {'_': 'PhotoSizeProgressive',
#         'type': 'x',
#         'w': 600,
#         'h': 315,
#         'sizes': [4208, 14195, 27815, 42357, 67214]}],
#       'dc_id': 4,
#       'has_stickers': False,
#       'video_sizes': []},
#      'embed_url': None,
#      'embed_type': None,
#      'embed_width': None,
#      'embed_height': None,
#      'duration': None,
#      'author': None,
#      'document': None,
#      'cached_page': None,
#      'attributes': []},
#     'force_large_media': False,
#     'force_small_media': False,
#     'manual': False,
#     'safe': True},
#    'reply_markup': None,
#    'entities': [{'_': 'MessageEntityUrl', 'offset': 0, 'length': 43}],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 115367,
#    'peer_id': {'_': 'PeerUser', 'user_id': 1144267645},
#    'date': '2021-08-17T10:37:32+00:00',
#    'message': 'А ты ещё не уволилась из Apple?) 🙄',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
# ...
#     'min': False,
#     'can_see_list': True,
#     'reactions_as_tags': False,
#     'recent_reactions': [{'_': 'MessagePeerReaction',
#       'peer_id': {'_': 'PeerUser', 'user_id': 5143670453},
#       'date': '2023-01-23T08:07:55+00:00',
#       'reaction': {'_': 'ReactionEmoji', 'emoticon': '🤩'},
#       'big': False,
#       'unread': False,
#       'my': False}],
#     'top_reactors': []},
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 196933,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 701406550},
#    'date': '2023-03-25T11:44:46+00:00',
#    'message': '',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaPhoto',
#     'spoiler': False,
#     'photo': {'_': 'Photo',
#      'id': 5258330823181059800,
#      'access_hash': -685219542147312442,
#      'file_reference': 'AwADAUVncm86ZXnoHUQDLL4Q0TtG5glXNQ==',
#      'date': '2023-03-25T11:44:45+00:00',
#      'sizes': [{'_': 'PhotoStrippedSize',
#        'type': 'i',
#        'bytes': 'ASgehsXAkOeh5/z+VXJbtI0Kx/e+nAqiB5UhX+6/6GtCRUdRuAK4qGUjI3FbjfnnIP8AjWnkmQ9OmarS2R8pplY8dAfSljvUBy8RJx2NMNhL9ClxuHRl/UVPE/mCMfw9affJuhDY5WoLQFUXP8JIzQ0JD5XkBZCcryOlUIo2lJxwBWjKpky0JBf9DVK0kC5DcZ5o6aDNRx5tufcZrMmz5SgfxcUUVRJo2i7IQKz7lFS6kHGM5/OiipQ2fw=='},
#       {'_': 'PhotoSize', 'type': 'm', 'w': 240, 'h': 320, 'size': 23436},
#       {'_': 'PhotoSize', 'type': 'x', 'w': 600, 'h': 800, 'size': 111149},
#       {'_': 'PhotoSizeProgressive',
#        'type': 'y',
#        'w': 960,
#        'h': 1280,
#        'sizes': [15460, 32861, 44305, 77345, 155151]}],
#      'dc_id': 2,
#      'has_stickers': False,
#      'video_sizes': []},
#     'ttl_seconds': None},
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': 13437957488469698,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 196932,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 701406550},
#    'date': '2023-03-25T11:44:46+00:00',
#    'message': 'Сыр, который мне нравится: вторая кастомная витрина с сырами, середина, первый ряд',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaPhoto',
#     'spoiler': False,
#     'photo': {'_': 'Photo',
#      'id': 5258330823181059799,
#      'access_hash': 7825809256397999529,
#      'file_reference': 'AwADAURncm86t2fiQtOrHMaI/JQSHejDlw==',
#      'date': '2023-03-25T11:44:41+00:00',
#      'sizes': [{'_': 'PhotoStrippedSize',
#        'type': 'i',
#        'bytes': 'ASgelQKsTk8HqKr7RKrMDlicH2qdtrAjPboeKqxKF34OCah6lIa7rv2A9OKa0ceAUYnscjvTCoSQBsgfSrOwzn92hEa9u9LYrctykbDVNMAntxVtiPLJPpWczuJBtbjPpTJJpVBwcDcen+FNhOxiyMRn3xU0ka5j4yrD1xg5qFy0EzAruU88HkGqSuJuxcYhLZmbntis1pQW2qOtFFKw7k+0+UCXyBjOR0FTR2yzq/JkZXIOaKKYjw=='},
#       {'_': 'PhotoSize', 'type': 'm', 'w': 240, 'h': 320, 'size': 32780},
#       {'_': 'PhotoSize', 'type': 'x', 'w': 600, 'h': 800, 'size': 166185},
#       {'_': 'PhotoSizeProgressive',
#        'type': 'y',
#        'w': 960,
#        'h': 1280,
#        'sizes': [18021, 49310, 78589, 133552, 245661]}],
#      'dc_id': 2,
#      'has_stickers': False,
#      'video_sizes': []},
#     'ttl_seconds': None},
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': 13437957488469698,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 196978,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 701406550},
#    'date': '2023-03-26T11:29:12+00:00',
#    'action': {'_': 'MessageActionChatAddUser', 'users': [463004712]},
#    'out': False,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'legacy': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 5143670453},
#    'reply_to': None,
#    'ttl_period': None},
#   {'id': 199426,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 701406550},
#    'date': '2023-04-17T16:10:41+00:00',
#    'message': 'Очень вкусный сыр - Gruyere Salé piccante',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaPhoto',
#     'spoiler': False,
#     'photo': {'_': 'Photo',
#      'id': 5325869140960987102,
#      'access_hash': 4764142148813799278,
#      'file_reference': 'AwADCwJncm86kk174mhN4mfuU7AEl8DiQA==',
#      'date': '2023-04-17T16:10:41+00:00',
#      'sizes': [{'_': 'PhotoStrippedSize',
#        'type': 'i',
#        'bytes': 'ASgepxQjZuzU8VsHYcn60W5DoIyenQdKmV9gKgFR69adhXIfs+yQyHlFGfx7frVcl/xq/DiVXQyZGNwGaqSYDcCk0ND44fMuRGrbD6+lWFRI/vSyMfqKWBztBTZv7kjmpS856hSPpU8y6lKNyERQxoXiXBPHWqEh2uQT9K0Skjfj2wKoX0flsuepzTTuDjYd5oJyUIPqKmFy6pnOR70UUWuK5Kt0cfMpFUb4lyrDpRRSSSBs'},
#       {'_': 'PhotoSize', 'type': 'm', 'w': 240, 'h': 320, 'size': 26281},
#       {'_': 'PhotoSize', 'type': 'x', 'w': 600, 'h': 800, 'size': 119161},
#       {'_': 'PhotoSizeProgressive',
#        'type': 'y',
#        'w': 960,
#        'h': 1280,
#        'sizes': [14991, 38615, 52283, 87894, 160552]}],
#      'dc_id': 2,
#      'has_stickers': False,
#      'video_sizes': []},
#     'ttl_seconds': None},
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 213368,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 701406550},
#    'date': '2023-07-26T15:51:14+00:00',
#    'message': '',
#    'out': False,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 463004712},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaPhoto',
#     'spoiler': False,
#     'photo': {'_': 'Photo',
#      'id': 5337064299635528379,
#      'access_hash': -4576339813218815994,
#      'file_reference': 'AQADQXhncm86zYcSMMs4XMWf8pxPjPurqQ==',
#      'date': '2023-07-26T15:51:13+00:00',
#      'sizes': [{'_': 'PhotoStrippedSize',
#        'type': 'i',
#        'bytes': 'ASgesSbY8JgYHNNWUHIHNQTyGebOMdqmjtxjOSKluw7EfrzTcZ5qc2+OQ9FuFIOetNO4rEEX+sBq4ApJbNUu1IQAOOKlq5VzQOAhx6VXhKsTkVWDH1NSwErk4z2qoqwmyiL71j/I0/7XG3UMKKKYhySo5wpzViFvJkYP0oooAw=='},
#       {'_': 'PhotoSize', 'type': 'm', 'w': 240, 'h': 320, 'size': 17194},
#       {'_': 'PhotoSize', 'type': 'x', 'w': 600, 'h': 800, 'size': 76427},
#       {'_': 'PhotoSizeProgressive',
#        'type': 'y',
#        'w': 960,
#        'h': 1280,
#        'sizes': [15900, 36144, 56094, 90221, 177903]}],
#      'dc_id': 2,
#      'has_stickers': False,
#      'video_sizes': []},
#     'ttl_seconds': None},
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 213484,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 701406550},
#    'date': '2023-07-26T17:29:41+00:00',
#    'message': '',
#    'out': False,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 463004712},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaPhoto',
#     'spoiler': False,
#     'photo': {'_': 'Photo',
#      'id': 5337064299635528495,
#      'access_hash': 2119907244260720070,
#      'file_reference': 'AQADQexncm86P2YE+QkTjGA49ymCXMyoZg==',
#      'date': '2023-07-26T17:29:40+00:00',
#      'sizes': [{'_': 'PhotoStrippedSize',
#        'type': 'i',
#        'bytes': 'ASgeqW7g3CD1NaOf3WKqadaBl+0SZ/2RWjvCDGP0oauCZVB5qQU8rHMpZRtYVCDmpZRLasptosdMCnSJ8/fHtVOCeK3xDuO3sT2q8rKw4NWTsV52dF24PPfHFVg7AnnFaMswjjJPJ6VnlQTz1qGUincQsrF/vA96ltpMIuCQQcdaKKpiRZMpbgnNJ3ooqRk='},
#       {'_': 'PhotoSize', 'type': 'm', 'w': 240, 'h': 320, 'size': 27197},
#       {'_': 'PhotoSize', 'type': 'x', 'w': 600, 'h': 800, 'size': 143450},
#       {'_': 'PhotoSizeProgressive',
#        'type': 'y',
#        'w': 960,
#        'h': 1280,
#        'sizes': [19204, 60143, 112838, 186604, 338330]}],
#      'dc_id': 2,
#      'has_stickers': False,
#      'video_sizes': []},
#     'ttl_seconds': None},
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 222258,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 701406550},
#    'date': '2023-09-26T10:59:28+00:00',
#    'message': 'Не брать',
#    'out': False,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 463004712},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaPhoto',
#     'spoiler': False,
#     'photo': {'_': 'Photo',
#      'id': 5231089683868538449,
#      'access_hash': -9109483041184395657,
#      'file_reference': 'AQADZDJncm86hbHVPtr7feisCWkxb1QutQ==',
#      'date': '2023-09-26T10:59:28+00:00',
#      'sizes': [{'_': 'PhotoStrippedSize',
#        'type': 'i',
#        'bytes': 'AR4orWbb3YHrjirRicHAByah0xcqx9TjNaG19wJ6j6UupXQiV2VPLHA6kUvkhucCobyXy3TPIJ5FW4wuwEHPHemnqS1oUbuJBGWxgiil1Q4jQDHXnFFVckTTSqw5PrVzzI9+ckVluzW6BYz9496nQS4zvH/fP/16hp3LuJqpz5bDkZqaFsoPmO3HHPFQy28kyje6jHoKazz26KG2MB9aYhdSK7EAPfpRVCeZppNx47AUVQg='},
#       {'_': 'PhotoSize', 'type': 'm', 'w': 320, 'h': 240, 'size': 25104},
#       {'_': 'PhotoSize', 'type': 'x', 'w': 800, 'h': 600, 'size': 116245},
#       {'_': 'PhotoSizeProgressive',
#        'type': 'y',
#        'w': 1280,
#        'h': 960,
#        'sizes': [15153, 35385, 50479, 82211, 157930]}],
#      'dc_id': 2,
#      'has_stickers': False,
#      'video_sizes': []},
#     'ttl_seconds': None},
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 222262,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 701406550},
#    'date': '2023-09-26T11:06:10+00:00',
#    'message': 'Апенйцллер вроде норм, а вот второй ужасный.',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': None,
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None},
#   {'id': 261072,
#    'peer_id': {'_': 'PeerChat', 'chat_id': 701406550},
#    'date': '2024-08-01T08:30:45+00:00',
#    'message': 'Эмменталь вкусный, терпкий\nГрюер пахнет, соленый\nАпенцеллер тоже пахнет, вкусный',
#    'out': True,
#    'mentioned': False,
#    'media_unread': False,
#    'silent': False,
#    'post': False,
#    'from_scheduled': False,
#    'legacy': False,
#    'edit_hide': False,
#    'pinned': False,
#    'noforwards': False,
#    'invert_media': False,
#    'offline': False,
#    'video_processing_pending': False,
#    'from_id': {'_': 'PeerUser', 'user_id': 291560340},
#    'from_boosts_applied': None,
#    'saved_peer_id': None,
#    'fwd_from': None,
#    'via_bot_id': None,
#    'via_business_bot_id': None,
#    'reply_to': None,
#    'media': {'_': 'MessageMediaPhoto',
#     'spoiler': False,
#     'photo': {'_': 'Photo',
#      'id': 5287678098491431729,
#      'access_hash': -5600281603592967173,
#      'file_reference': 'AwAD+9Bncm86Y476cFmLEZC8QrwSz03RRg==',
#      'date': '2024-08-01T08:30:45+00:00',
#      'sizes': [{'_': 'PhotoStrippedSize',
#        'type': 'i',
#        'bytes': 'AR4opJP5rBFTb6nrVoHkKFJbviorSIeb7nj6VoKqjlcZ9TSbQ9SAPIv/ACxY+4FJLMvKspU+hHBq5l9pyQPeoypk+WQK6+oouBTVyWHl55oqSWLyJMp0I4oo0HdiQjy2UnA7VY8o54PHpVdTvjU+opVuWiXBG5e3rUrswZbCnGDjFHl46Eiq63yEZ2tTWvSTtRce5ppJC3JbojATqaKhXJO5jkmipbKSPw=='},
#       {'_': 'PhotoSize', 'type': 'm', 'w': 320, 'h': 240, 'size': 22387},
#       {'_': 'PhotoSize', 'type': 'x', 'w': 800, 'h': 600, 'size': 95388},
#       {'_': 'PhotoSizeProgressive',
#        'type': 'y',
#        'w': 1280,
#        'h': 960,
#        'sizes': [14515, 31880, 39721, 66542, 127222]}],
#      'dc_id': 2,
#      'has_stickers': False,
#      'video_sizes': []},
#     'ttl_seconds': None},
#    'reply_markup': None,
#    'entities': [],
#    'views': None,
#    'forwards': None,
#    'replies': None,
#    'edit_date': None,
#    'post_author': None,
#    'grouped_id': None,
#    'reactions': None,
#    'restriction_reason': [],
#    'ttl_period': None,
#    'quick_reply_shortcut_id': None,
#    'effect': None,
#    'factcheck': None}],
#  '5770065782': [<telethon.tl.patched.Message at 0x168afb8d0>,
#   <telethon.tl.patched.Message at 0x168afbed0>,
#   <telethon.tl.patched.Message at 0x168afbe50>,
#   <telethon.tl.patched.Message at 0x168afb890>,
#   <telethon.tl.patched.Message at 0x168afb950>]}

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 mm = load_messages()
#
# Cell In[54], line 23, in load_messages(path)
#      21         for vv in v:
#      22             d = json.loads(vv)
# ---> 23             data_type = type_map[d.pop("_")]
#      24             messages[k].append(data_type(d))
#      25 return messages
#
# KeyError: 'MessageService'
