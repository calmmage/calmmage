# %%
print(1)
import sys

print(sys.path)
print(2)
# Out:
# 1
# ['/nix/store/cgc094j7jm0dm4xj0v1hy4361pji4ys6-python3-3.11.10/lib/python311.zip', '/nix/store/cgc094j7jm0dm4xj0v1hy4361pji4ys6-python3-3.11.10/lib/python3.11', '/nix/store/cgc094j7jm0dm4xj0v1hy4361pji4ys6-python3-3.11.10/lib/python3.11/lib-dynload', '', '/Users/petrlavrov/work/projects/calmmage/.venv/lib/python3.11/site-packages', '/Users/petrlavrov/work/projects/calmmage']
# 2

# %%
import botspot

# %%
# option 1: use pyrogram

# %%
# option 2: use telethon

import telethon

from telethon import TelegramClient
from dotenv import load_dotenv
import os

load_dotenv()

# These example values won't work. You must get your own api_id and 
# api_hash from https://my.telegram.org, under API Development.
api_id = int(os.getenv('TELEGRAM_API_ID'))
api_hash = os.getenv('TELEGRAM_API_HASH')

# Create the client and connect
client = TelegramClient('anon', api_id, api_hash)


async def main():
    # Start the client
    await client.start()
    print("Client Created")

    # Ensure you're authorized
    if await client.is_user_authorized():
        print('Successfully authenticated!')
    else:
        print('Authentication failed. Please check your credentials.')

    await client.disconnect()


# Run the client
await client.run_until_disconnected()
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[12], line 33
#      30     await client.disconnect()
#      32 # Run the client
# ---> 33 await client.run_until_disconnected()
#
# File ~/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/client/updates.py:35, in UpdateMethods._run_until_disconnected(self)
#      32 async def _run_until_disconnected(self: 'TelegramClient'):
#      33     try:
#      34         # Make a high-level request to notify that we want updates
# ---> 35         await self(functions.updates.GetStateRequest())
#      36         result = await self.disconnected
#      37         if self._updates_error is not None:
#
# File ~/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/client/users.py:30, in UserMethods.__call__(self, request, ordered, flood_sleep_threshold)
#      29 async def __call__(self: 'TelegramClient', request, ordered=False, flood_sleep_threshold=None):
# ---> 30     return await self._call(self._sender, request, ordered=ordered)
#
# File ~/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/client/users.py:67, in UserMethods._call(self, sender, request, ordered, flood_sleep_threshold)
#      65 for attempt in retry_range(self._request_retries):
#      66     try:
# ---> 67         future = sender.send(request, ordered=ordered)
#      68         if isinstance(future, list):
#      69             results = []
#
# File ~/work/projects/calmmage/.venv/lib/python3.11/site-packages/telethon/network/mtprotosender.py:179, in MTProtoSender.send(self, request, ordered)
#     156 """
#     157 This method enqueues the given request to be sent. Its send
#     158 state will be saved until a response arrives, and a ``Future``
#    (...)
#     176 impossible to await receive a result that was never sent.
#     177 """
#     178 if not self._user_connected:
# --> 179     raise ConnectionError('Cannot send requests while disconnected')
#     181 if not utils.is_list_like(request):
#     182     try:
#
# ConnectionError: Cannot send requests while disconnected
