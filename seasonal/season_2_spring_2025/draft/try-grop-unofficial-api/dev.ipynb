# %%
print(1)
# Out:
# Running cells with 'Python 3.13.1' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import os

# %%
import sys

# %%
sys.path
# Out:
# ['/Users/petrlavrov/work/projects/calmmage/seasonal/season_2_feb-mar_2025/draft/try-grop-unofficial-api',
#  '/Users/petrlavrov/Applications/PyCharm Professional Edition.app/Contents/plugins/python-ce/helpers/pydev',
#  '/Users/petrlavrov/Applications/PyCharm Professional Edition.app/Contents/plugins/python/helpers-pro/jupyter_debug',
#  '/opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python313.zip',
#  '/opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13',
#  '/opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload',
#  '',
#  '/Users/petrlavrov/work/projects/.venv/lib/python3.13/site-packages',
#  '/Users/petrlavrov/work/projects/.venv/lib/python3.13/site-packages/setuptools/_vendor']
