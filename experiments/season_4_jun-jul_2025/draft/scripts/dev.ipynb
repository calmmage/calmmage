# %%
print(1)

# %%
import pandas as pd

df = pd.read_csv('data/switzerland_activities.tsv', sep='\t')

df.head()

# save back to csv, no index
df.to_csv('data/switzerland_activities.csv', index=False)
